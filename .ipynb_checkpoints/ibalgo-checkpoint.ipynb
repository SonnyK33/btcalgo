# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from math import sqrt
import pandas_ta as ta
from arch import arch_model
import numpy as np
from ib_insync import *
from collections import deque
from enum import Enum
import datetime
import logging
import math
util.startLoop()

# %%
"""start here
TODO's:
1) get list of simple trending strategies (have MA, finish EMA, maybe couple more)
2) combine them? or just use one? look at the Carver example on Github
3) back to actual trading - how to run for >1 contracts? may require multiple threads
4) run live (paper trading) in cloud 


"""

# %%
"""logging parameters"""
today = datetime.datetime.today().date()
logging.basicConfig(level = logging.INFO,
                   filename = 'algo_log_'+str(today)+'_.log',
                   filemode='w')

# %%
contract_dict = {'Stock':Stock, 'Crypto':Crypto}

class Algo():
    def __init__(self, client, addr, port, client_id):
        self.client = client
        self.addr = addr
        self.port = port
        self.client_id = client_id
        
        self.client.connect(addr, port, client_id)
        
    def SetPaperBalances(self):
        self.USD_balance = 1000
        self.BTC_balance = 0
        
        print('USD balance: {}'.format(self.USD_balance))
        print('BTC balance: {}'.format(self.BTC_balance))
    
    def GetContract(self, contract_type, ticker, exchange, currency):
        return contract_dict[contract_type](ticker, exchange, currency)
    
    def GetHistoricalData(self, contract, duration='1 D', bar_size='1 hour'):
        bars = ib.reqHistoricalData(contract=contract, endDateTime='', durationStr=duration,
                                    barSizeSetting=bar_size, whatToShow='MIDPOINT', useRTH=True)
        return bars
    
    def BuildEMA(self, slow_period, fast_period):
        """using deques instead of dataframes"""
        self.slow_ema = deque(maxlen=slow_period)
        self.fast_ema = deque(maxlen=fast_period)
        
        """need to employ scanner to pull in data"""
        
           
    def GetDMI(self, df):
        df_adx = ta.adx(high=df['high'], low=df['low'], close=df['close'])
        df['ADX'] = df_adx['ADX_14']
        df['DMN'] = df_adx['DMN_14']
        df['DMP'] = df_adx['DMP_14']
        df['DM_diff'] = df['DMP'] > df['DMN']
        return df
        
    
    
    def GetMovingAverages(self, df, low, high, plot=True):
#         print('length:', len(df))
        df_MA = df.copy()
        if len(df) < high:
            return
#         display('in mov avg fn', df_MA)
        
        df_MA[str(low)+'_average'] = df.close.rolling(low).mean()
        df_MA[str(high)+'_average'] = df.close.rolling(high).mean()
#         df_MA.dropna(inplace=True)
        df_MA['MA_diff'] = df_MA[str(high)+'_average'] > df_MA[str(low)+'_average']
        
        if plot:
            df_MA['close'].plot(legend=True)
            df_MA[str(low)+'_average'].plot(legend=True)
            df_MA[str(high)+'_average'].plot(legend=True)
        
#         display('end of mov avg', df_MA)
        return df_MA
    
    
    def PlacePaperOrder(self, order_type, price=None, quantity=None, date=None):
        print('placing order:', order_type)

        if order_type=='sell':
            print(date)
            print('{} @ {}'.format(order_type, price))
            self.BTC_balance -= quantity
            self.USD_balance += quantity * price
            

        elif order_type=='buy':
            print(date)
            print('{} @ {}'.format(order_type, price))
            self.BTC_balance += quantity
            self.USD_balance -= quantity * price

        else:
            return 


        print('USD balance: {}'.format(self.USD_balance))
        print('BTC balance: {}'.format(self.BTC_balance))
        account_balance = self.USD_balance + self.BTC_balance * price
        print('Account balance: {}\n'.format(account_balance))       

    def RunDMI(self, df, ADX_MIN=20):
        for count, row in enumerate(df.iterrows()):
            if count==0:
                sentiment = row[1]['DM_diff']
            else:
                if (row[1]['ADX'] >= ADX_MIN):
                    if row[1]['DM_diff'] == sentiment:
                        self.PlacePaperOrder('no change')
                    else:
                        if row[1]['DM_diff']:
                            self.PlacePaperOrder('buy',row[1]['close'],1, row[1]['date'])
                        else:
                            self.PlacePaperOrder('sell', row[1]['close'],1, row[1]['date'])
                    sentiment = row[1]['DM_diff']
                else: continue                                     
                        
    
    def RunStrategy(self, df):   

        for count, row in enumerate(df.iterrows()):
            if count==0:
                sentiment = row[1]['MA_diff']
            else:
                if row[1]['MA_diff'] == sentiment:
                    self.PlacePaperOrder('no change')
                else:
                    if row[1]['MA_diff']:
                        self.PlacePaperOrder('sell',row[1]['close'],1)
                    else:
                        self.PlacePaperOrder('buy', row[1]['close'],1)
                    sentiment = row[1]['MA_diff']


def Main(client_id):
    
    ib = IB()
    algo = Algo(ib, '127.0.0.1', 7497, client_id=client_id)
    
    contract = algo.GetContract('Crypto','BTC', 'PAXOS', 'USD')
    
    bars = algo.GetHistoricalData(contract, '180 D', '1 day')
    
    df = util.df(bars)
    
    algo.SetPaperBalances()
    
#     df_MA =  algo.GetMovingAverages(df, 10, 30, True)
    df_DMI = algo.GetDMI(df)
    
#     algo.RunStrategy(df_MA)
    algo.RunDMI(df_DMI)
    
    print('USD balance: {}'.format(algo.USD_balance))
    print('BTC balance: {}'.format(algo.BTC_balance))

    account_value = algo.USD_balance + algo.BTC_balance * bars[-1].close
    print('Account value: {}'.format(account_value))

# %%
class Account():
    def __init__(self, USD_balance: int, BTC_balance: int, BTC_price: float = None):
        self.USD_balance = USD_balance
        self.BTC_balance = BTC_balance
        self.BTC_price = BTC_price                 
        self.df_account = pd.DataFrame(columns=['Date', 'USD', 'BTC', 'Account Value', 'BTC Px'])
        self.log = dict()
        
    def __call__(self):
        return self.returnBalance()
        
    def __repr__(self):
        return 'USD balance: '+ str(self.USD_balance) + '\nBTC balance: ' + str(self.BTC_balance) + '\nAccount Value: '+str(self.USD_balance + self.BTC_balance * self.BTC_price) + '\nBTC Price:' + str(self.BTC_price)
        
        
    def updateBTCPrice(self, BTC_price: float):
        self.BTC_price = BTC_price
        
    def closePosition(self):
        self.BTC_balance = 0
        self.USD_balance -= self.BTC_balance * self.BTC_price
    
    def tradeBTC(self, signal: Signal, quantity: int, date: datetime): #-> order:
#         print(signal)
#         print(str(signal), str(quantity)+' @ ', str(self.BTC_price))
#         logging.info(str(signal), str(quantity)+' @ ', str(self.BTC_price))
        
        self.log[str(date)] = str(signal) + str(quantity)
        logging.info("%s, %s @, %s" %(signal, quantity, self.BTC_price))
        
        #first exit current position if there is one 
        if self.BTC_balance != 0:
            self.USD_balance += self.BTC_balance * self.BTC_price
            self.BTC_balance = 0
        
        direction = 1 if signal==Signal.BUY else -1
        
        self.BTC_balance += direction * quantity
        self.USD_balance -= direction * quantity * self.BTC_price
        
        order_type = 'BUY' if signal==Signal.BUY else 'SELL'
        
        order = LimitOrder(order_type, quantity, round(self.BTC_price, 0),
                           tif='GTC')
        return order 
        
#         self.updateBalance([date, self.USD_balance, self.BTC_balance, self.total])
                
    def updateBalance(self, date):
        total = self.USD_balance + self.BTC_balance * self.BTC_price
        self.df_account.loc[len(self.df_account.index)] = [date, self.USD_balance,
                                                          self.BTC_balance, total, self.BTC_price]       
        
    def returnBalance(self):
        return self.df_account
    
    def plotBalance(self):
        self.df_account.plot(x='Date', y=['Account Value'])

# %%
"""real time updates"""

from collections import deque
import pandas as pd


Sentiment = Enum('Sentiment','BEAR NEUTRAL BULL')
Signal = Enum('Signal','BUY SELL')

strategy_dict = dict()

def AddStrategy(strategy_fn):
    strategy_dict[strategy_fn.__name__] = strategy_fn
    return strategy_fn
  
def LogFunctionCall(fn):
    logging.info(fn.__name__+' called')
    return fn

def PrintFunction(fn):
    print(fn)
#     print(fn.__code__.co_varnames)
    return fn
    


class Strategy():
    def __init__(self, account: Account, ib, client_id: int, paper_trading: bool = True):
        self.client_id = client_id
        self.ib = ib     
        self.algo = Algo(ib, '127.0.0.1', 7497, client_id=self.client_id)
        self.algo.SetPaperBalances()
        self.contract = Crypto('BTC', exchange='PAXOS', currency='USD')
        self.account = account
        self.paper_trading=paper_trading
        self.sentiment = dict()
        self.signal = dict()
        self.trades = list()


    
    def onBarUpdate(self, bars, newBar):
        if newBar:
            print('on bar update', bars[-1])
            self.strategy_params['close'] = bars[-1].close 
            self.strategy(**self.strategy_params)
    #         self.low_deque.append(bars[-1].close)
    #         self.high_deque.append(bars[-1].close)
    #         self.account.updateBTCPrice(BTC_price=bars[-1].close)
    #         self.MovingAverage(self.low_deque, self.high_deque, bars[-1].close)
            self.SignalProcess(self.strategy.__name__, date=bars[-1].time)
    
#     def MovingAverage(self, low_deque, high_deque, closing_value):
  
    
    @AddStrategy
    @LogFunctionCall
    def EMAverage(self, smoothing, period, close):
        if not hasattr(self, "SMA_lst"):
            self.SMA_lst = []
        
        self.SMA_lst.append(close)
        
        if len(self.SMA_lst) < period:            
            return            
        
        k = smoothing / (1 + period)
        
        if len(self.SMA_lst) == period:            
            self.EMA = np.array([])
            self.EMA = np.append(self.EMA,sum(self.SMA_lst[0:period])/period)
            return
        
        new_value = close * k  + self.EMA[-1] * (1 - k)
        self.EMA = np.append(EMA, new_value)
        
        """below code should be made abstract as is repeated for every strategy"""
        
        if close < self.EMA[-1]:
            current_sentiment_EMA = Sentiment.BEAR
        elif close > self.EMA[-1]:
            current_sentiment_EMA = Sentiment.BULL
        else:
            current_sentiment_EMA = Sentiment.NEUTRAL       
        
        if self.sentiment.get('ExpMovingAverage') is None:
            print('1st setting of EMA sentiment')
            self.sentiment['ExpMovingAverage'] = current_sentiment_EMA
            return

        if self.sentiment['ExpMovingAverage'] != current_sentiment_EMA:
            print('change in sentiment')
            
            if current_sentiment_EMA == Sentiment.BEAR:
                self.signal['ExpMovingAverage'] = Signal.SELL               

            elif current_sentiment_EMA == Sentiment.BULL:
                self.signal['ExpMovingAverage'] = Signal.BUY            
            print(self.signal['ExpMovingAverage'])

                              
        self.sentiment['ExpMovingAverage'] = current_sentiment_EMA
        
        
      


        
    
    
    @AddStrategy
    @LogFunctionCall
    def MovingAverage(self, low, high, close):

        
        if not (hasattr(self, "low_deque") and hasattr(self, "high_deque")):
            low_deque_len, high_deque_len = low, high
            self.low_deque = deque(maxlen=low_deque_len)
            self.high_deque = deque(maxlen=high_deque_len)              

        self.low_deque.append(close)
        self.high_deque.append(close)
        self.account.updateBTCPrice(BTC_price=close)        
        
        if len(self.high_deque) < self.high_deque.maxlen:
            return
        low_avg = sum(self.low_deque)/len(self.low_deque)
        high_avg = sum(self.high_deque)/len(self.high_deque)

        if low_avg < high_avg:
            current_sentiment_MA = Sentiment.BEAR
        elif low_avg > high_avg:
            current_sentiment_MA = Sentiment.BULL
        else:
            current_sentiment_MA = Sentiment.NEUTRAL
        
#         print('low avg:', low_avg, 'high avg:', high_avg)
        
        if self.sentiment.get('MovingAverage') is None:
            print('1st setting of MA sentiment')
            self.sentiment['MovingAverage'] = current_sentiment_MA
            return

        if self.sentiment['MovingAverage'] != current_sentiment_MA:
            print('change in sentiment')
#             print('previous sentiment:', self.sentiment.get('MovingAverage'))
#             print('current sentiment:', current_sentiment_MA)
            
            if current_sentiment_MA == Sentiment.BEAR:
                self.signal['MovingAverage'] = Signal.SELL               

            elif current_sentiment_MA == Sentiment.BULL:
                self.signal['MovingAverage'] = Signal.BUY            
            print(self.signal['MovingAverage'])
#         else:
#             print('no trades')
                              
        self.sentiment['MovingAverage'] = current_sentiment_MA
#         print('current sentiment: ', current_sentiment_MA)
        
#         previous sentiment: Sentiment.BULL
# current sentiment: Sentiment.BEAR
# Signal.SELL
# current sentiment:  Sentiment.BEAR
# signals: []
        
        
    @LogFunctionCall
    @PrintFunction
    def SignalProcess(self, *signals, date):        
        signal_list = [values for keys,values in self.signal.items() if keys in signals]
        print(signal_list)
        
        
        if len(set(signal_list))==1 and signal_list[0] is not None: #i.e. all signals are the same
            print(date)
            signal = signal_list[0]
            print(str(signal) + ' @ ' + str(self.account.BTC_price))
            order = self.account.tradeBTC(signal=signal, quantity=1, date=date)
            
            if not self.paper_trading:
                self.trades.append(self.ib.placeOrder(self.contract, order))
            
            self.ClearSignals(*signals)                
        
        self.account.updateBalance(date=date)
        print(self.account)
    
    def ClearSignals(self, *signals):
        for s in signals:
            self.signal[s]=None                  

    def SetStrategy(self, strategy, **kwargs):
#         self.strategy_name=strategy
        self.strategy = strategy_dict[strategy]
        self.strategy_params = kwargs
        self.strategy_params['self'] = self
        
        
    
    def RunStrategy(self):       
       
#         low, high = 5, 10
#         self.low_deque = deque(maxlen=low)
#         self.high_deque = deque(maxlen=high)

        bars = ib.reqRealTimeBars(contract=self.contract,
                                  barSize=5,
                                  whatToShow='MIDPOINT',
                                 useRTH=False)
        bars.updateEvent += self.onBarUpdate


        self.ib.sleep(100)
        self.ib.cancelRealTimeBars(bars)        
    
        
    def Backtest(self, duration='360 D', barSize='1 day'):
        self.paper_trading = True
        bars = ib.reqHistoricalData(
            self.contract, endDateTime='', durationStr=duration,
            barSizeSetting=barSize, whatToShow='MIDPOINT', useRTH=True)
        
        df = util.df(bars)
#         display(df.head(5), df.tail(5))
             
#         low, high = 5, 10
#         low_deque = deque(maxlen=low)
#         high_deque = deque(maxlen=high)
        
        for row in df.itertuples(name='bar', index=False):    
            self.strategy_params['close'] = row.close 
            self.strategy(**self.strategy_params)    
            self.SignalProcess(self.strategy.__name__, date=row.date)
            
    def PlotEquityCurve(self):
        fig, axs = plt.subplots(2, figsize=(15,15))
        date = self.account.df_account['Date']
        axs[0].title.set_text('Account Value')
        axs[1].title.set_text('BTC Price')
        axs[0].plot(date, self.account.df_account['Account Value'])
        axs[1].plot(date, self.account.df_account['BTC Px'])
            
            
#             low_deque.append(row.close)
#             high_deque.append(row.close)
#             self.account.updateBTCPrice(BTC_price=row.close)
#             self.MovingAverage(low_deque, high_deque, row.close)
#             self.SignalProcess('MA', date=row.date)
# Out:
# <function Strategy.SignalProcess at 0x0000020A6F279310>

# %%
ib = IB()
account = Account(USD_balance=1000, BTC_balance=0)
S = Strategy(account, ib, 1, paper_trading=True)

S.SetStrategy('MovingAverage',low=10,high=30)

# S.RunStrategy()
    
S.Backtest()
# account.plotBalance()
# Out:
# USD balance: 1000
# BTC balance: 0
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48708.125
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:49240.875
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48260.125
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48667.875
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46951.5
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48335.125
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48647.125
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:47340.625
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48158.625
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:49328.375
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:50556.375
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:51739.375
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46702.25
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46454.625
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46608.875
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:45647.625
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:44766.875
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46483.0
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48094.875
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:47456.625
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:47508.375
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:43873.125
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:42009.125
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:43444.5
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:44796.875
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:42416.125
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:43050.875
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:41593.0
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:41179.625
# 1st setting of MA sentiment
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:43586.625
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48038.25
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:49362.875
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:51204.375
# []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:55078.625
# change in sentiment
# Signal.BUY
# [<Signal.BUY: 1>]
# 2021-10-07
# Signal.BUY @ 53987.125
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 1000.0
# BTC Price:53987.125
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 1712.75
# BTC Price:54699.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 4526.0
# BTC Price:57513.125
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 2340.0
# BTC Price:55327.125
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 4281.0
# BTC Price:57268.125
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 4870.0
# BTC Price:57857.125
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 8458.25
# BTC Price:61445.375
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 8440.75
# BTC Price:61427.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 11221.75
# BTC Price:64208.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 13415.75
# BTC Price:66402.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 9837.375
# BTC Price:62824.5
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 8013.0
# BTC Price:61000.125
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 9675.75
# BTC Price:62662.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 9006.75
# BTC Price:61993.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 6116.5
# BTC Price:59103.625
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 8366.75
# BTC Price:61353.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 9552.25
# BTC Price:62539.375
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 8466.75
# BTC Price:61453.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 10648.5
# BTC Price:63635.625
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 9895.75
# BTC Price:62882.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 8284.75
# BTC Price:61271.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 8173.75
# BTC Price:61160.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 13097.75
# BTC Price:66084.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 14371.25
# BTC Price:67358.375
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 12853.125
# BTC Price:65840.25
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 11860.375
# BTC Price:64847.5
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 11151.75
# BTC Price:64138.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 10947.5
# BTC Price:63934.625
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 6771.375
# BTC Price:59758.5
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 7449.75
# BTC Price:60436.875
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 5023.375
# BTC Price:58010.5
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 4886.25
# BTC Price:57873.375
# [None]
# USD balance: -52987.125
# BTC balance: 1
# Account Value: 2924.75
# BTC Price:55911.875
# change in sentiment
# Signal.SELL
# [<Signal.SELL: 2>]
# 2021-11-23
# Signal.SELL @ 57863.625
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 4876.5
# BTC Price:57863.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 5315.25
# BTC Price:57424.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 3819.75
# BTC Price:58920.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 8177.75
# BTC Price:54562.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 4640.875
# BTC Price:58099.25
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 5240.125
# BTC Price:57500.0
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 5930.0
# BTC Price:56810.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 5688.0
# BTC Price:57052.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 9248.5
# BTC Price:53491.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 13847.75
# BTC Price:48892.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 12282.875
# BTC Price:50457.25
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 11966.0
# BTC Price:50774.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 15054.0
# BTC Price:47686.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 14279.75
# BTC Price:48460.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 16110.25
# BTC Price:46629.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 14929.75
# BTC Price:47810.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 13504.5
# BTC Price:49235.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 14803.75
# BTC Price:47936.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 16536.5
# BTC Price:46203.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 15717.75
# BTC Price:47022.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 14102.5
# BTC Price:48637.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 13766.5
# BTC Price:48973.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 11740.0
# BTC Price:51000.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 11599.75
# BTC Price:51140.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 11493.0
# BTC Price:51247.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 14926.75
# BTC Price:47813.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 15360.25
# BTC Price:47379.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 15537.5
# BTC Price:47202.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 16857.0
# BTC Price:45883.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 16820.0
# BTC Price:45920.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 16461.0
# BTC Price:46279.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 18779.875
# BTC Price:43960.25
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 19524.25
# BTC Price:43215.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 20813.0
# BTC Price:41927.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 21004.125
# BTC Price:41736.0
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 19942.5
# BTC Price:42797.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 18895.0
# BTC Price:43845.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 19926.0
# BTC Price:42814.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 19598.25
# BTC Price:43141.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 20622.5
# BTC Price:42117.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 20953.25
# BTC Price:41786.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 21116.75
# BTC Price:41623.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 20032.25
# BTC Price:42707.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 24361.375
# BTC Price:38378.75
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 25486.375
# BTC Price:37253.75
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 25839.0
# BTC Price:36901.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 25692.125
# BTC Price:37048.0
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 27182.75
# BTC Price:35557.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 24956.25
# BTC Price:37783.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 24241.0
# BTC Price:38499.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 24210.75
# BTC Price:38529.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 25131.75
# BTC Price:37608.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 26370.5
# BTC Price:36369.625
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 22139.25
# BTC Price:40600.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 18564.375
# BTC Price:44175.75
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 18441.25
# BTC Price:44298.875
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 17951.0
# BTC Price:44789.125
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 18626.75
# BTC Price:44113.375
# [None]
# USD balance: 62740.125
# BTC balance: -1
# Account Value: 20392.5
# BTC Price:42347.625
# change in sentiment
# Signal.BUY
# [<Signal.BUY: 1>]
# 2022-02-14
# Signal.BUY @ 42200.375
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 20539.75
# BTC Price:42200.375
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 22502.75
# BTC Price:44163.375
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 22475.0
# BTC Price:44135.625
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 19237.5
# BTC Price:40898.125
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 18370.5
# BTC Price:40031.125
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 16582.25
# BTC Price:38242.875
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 16281.5
# BTC Price:37942.125
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 16027.25
# BTC Price:37687.875
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 16751.125
# BTC Price:38411.75
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 17477.75
# BTC Price:39138.375
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 20267.25
# BTC Price:41927.875
# [None]
# USD balance: -21660.625
# BTC balance: 1
# Account Value: 22456.75
# BTC Price:44117.375
# change in sentiment
# Signal.SELL
# [<Signal.SELL: 2>]
# 2022-03-02
# Signal.SELL @ 43827.625
# USD balance: 65994.625
# BTC balance: -1
# Account Value: 22167.0
# BTC Price:43827.625
# change in sentiment
# Signal.BUY
# [<Signal.BUY: 1>]
# 2022-03-03
# Signal.BUY @ 42026.375
# USD balance: -18058.125
# BTC balance: 1
# Account Value: 23968.25
# BTC Price:42026.375
# change in sentiment
# Signal.SELL
# [<Signal.SELL: 2>]
# 2022-03-04
# Signal.SELL @ 39510.875
# USD balance: 60963.625
# BTC balance: -1
# Account Value: 21452.75
# BTC Price:39510.875
# [None]
# USD balance: 60963.625
# BTC balance: -1
# Account Value: 23383.0
# BTC Price:37580.625
# [None]
# USD balance: 60963.625
# BTC balance: -1
# Account Value: 22442.375
# BTC Price:38521.25
# change in sentiment
# Signal.BUY
# [<Signal.BUY: 1>]
# 2022-03-09
# Signal.BUY @ 41816.375
# USD balance: -22669.125
# BTC balance: 1
# Account Value: 19147.25
# BTC Price:41816.375
# [None]
# USD balance: -22669.125
# BTC balance: 1
# Account Value: 16972.0
# BTC Price:39641.125
# [None]
# USD balance: -22669.125
# BTC balance: 1
# Account Value: 15698.75
# BTC Price:38367.875
# change in sentiment
# Signal.SELL
# [<Signal.SELL: 2>]
# 2022-03-14
# Signal.SELL @ 38808.375
# USD balance: 54947.625
# BTC balance: -1
# Account Value: 16139.25
# BTC Price:38808.375
# [None]
# USD balance: 54947.625
# BTC balance: -1
# Account Value: 15199.75
# BTC Price:39747.875
# [None]
# USD balance: 54947.625
# BTC balance: -1
# Account Value: 14054.5
# BTC Price:40893.125
# [None]
# USD balance: 54947.625
# BTC balance: -1
# Account Value: 14075.0
# BTC Price:40872.625
# [None]
# USD balance: 54947.625
# BTC balance: -1
# Account Value: 12880.75
# BTC Price:42066.875
# [None]
# USD balance: 54947.625
# BTC balance: -1
# Account Value: 13754.75
# BTC Price:41192.875
# [None]
# USD balance: 54947.625
# BTC balance: -1
# Account Value: 12640.5
# BTC Price:42307.125
# [None]
# USD balance: 54947.625
# BTC balance: -1
# Account Value: 12698.25
# BTC Price:42249.375
# change in sentiment
# Signal.BUY
# [<Signal.BUY: 1>]
# 2022-03-24
# Signal.BUY @ 43946.125
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 11001.5
# BTC Price:43946.125
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 11524.5
# BTC Price:44469.125
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 15034.75
# BTC Price:47979.375
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 14791.0
# BTC Price:47735.625
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 14130.5
# BTC Price:47075.125
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 12679.75
# BTC Price:45624.375
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 13449.25
# BTC Price:46393.875
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 13011.0
# BTC Price:45955.625
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 13084.0
# BTC Price:46028.625
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 10813.5
# BTC Price:43758.125
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 10465.5
# BTC Price:43410.125
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 9794.25
# BTC Price:42738.875
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 7053.5
# BTC Price:39998.125
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 6349.5
# BTC Price:39294.125
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 8141.75
# BTC Price:41086.375
# [None]
# USD balance: -32944.625
# BTC balance: 1
# Account Value: 6838.25
# BTC Price:39782.875
# change in sentiment
# Signal.SELL
# [<Signal.SELL: 2>]
# 2022-04-15
# Signal.SELL @ 40323.625
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 7379.0
# BTC Price:40323.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 7012.75
# BTC Price:40689.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 6247.5
# BTC Price:41455.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 6512.5
# BTC Price:41190.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 6457.5
# BTC Price:41245.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 8212.75
# BTC Price:39489.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 7459.25
# BTC Price:40243.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 9409.25
# BTC Price:38293.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 8834.0
# BTC Price:38868.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 7736.25
# BTC Price:39966.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 9372.5
# BTC Price:38330.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 9159.75
# BTC Price:38542.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 9996.5
# BTC Price:37706.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 7858.25
# BTC Price:39844.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 11376.0
# BTC Price:36326.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 11724.75
# BTC Price:35977.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 16754.625
# BTC Price:30948.0
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 16361.0
# BTC Price:31341.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18402.25
# BTC Price:29300.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 19137.25
# BTC Price:28565.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 17660.75
# BTC Price:30041.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18141.75
# BTC Price:29560.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 17644.75
# BTC Price:30057.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18451.5
# BTC Price:29251.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 17763.75
# BTC Price:29938.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18429.75
# BTC Price:29272.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18640.75
# BTC Price:29061.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18353.0
# BTC Price:29349.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18149.75
# BTC Price:29552.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18347.25
# BTC Price:29355.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18847.75
# BTC Price:28854.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 17079.0
# BTC Price:30623.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 16085.5
# BTC Price:31617.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 17609.25
# BTC Price:30093.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 17432.0
# BTC Price:30270.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18149.5
# BTC Price:29553.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 16252.0
# BTC Price:31450.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 16661.25
# BTC Price:31041.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 17581.5
# BTC Price:30121.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 17711.375
# BTC Price:29991.25
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 18743.75
# BTC Price:28958.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 24560.625
# BTC Price:23142.0
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 25534.0
# BTC Price:22168.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 26102.375
# BTC Price:21600.25
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 26847.875
# BTC Price:20854.75
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27201.75
# BTC Price:20500.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27646.875
# BTC Price:20055.75
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 26828.75
# BTC Price:20873.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27596.25
# BTC Price:20106.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 26807.75
# BTC Price:20894.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 26469.25
# BTC Price:21233.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 26853.25
# BTC Price:20849.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27457.5
# BTC Price:20245.125
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27506.75
# BTC Price:20195.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 28793.625
# BTC Price:18909.0
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 28338.25
# BTC Price:19364.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27898.25
# BTC Price:19804.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27322.75
# BTC Price:20379.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27401.0
# BTC Price:20301.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 25887.0
# BTC Price:21815.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 25906.75
# BTC Price:21795.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27211.625
# BTC Price:20491.0
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 28319.75
# BTC Price:19382.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 28068.25
# BTC Price:19634.375
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 27108.75
# BTC Price:20593.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 26546.75
# BTC Price:21155.875
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 26089.375
# BTC Price:21613.25
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 24294.0
# BTC Price:23408.625
# [None]
# USD balance: 47702.625
# BTC balance: -1
# Account Value: 24042.0
# BTC Price:23660.625
# change in sentiment
# Signal.BUY
# [<Signal.BUY: 1>]
# 2022-07-21
# Signal.BUY @ 23192.625
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24510.0
# BTC Price:23192.625
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 23916.875
# BTC Price:22599.5
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 23208.5
# BTC Price:21891.125
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 22237.75
# BTC Price:20920.375
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24081.75
# BTC Price:22764.375
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 25115.625
# BTC Price:23798.25
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 25226.25
# BTC Price:23908.875
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24283.25
# BTC Price:22965.875
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24279.25
# BTC Price:22961.875
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24784.25
# BTC Price:23466.875
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 23777.75
# BTC Price:22460.375
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24265.25
# BTC Price:22947.875
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 25246.0
# BTC Price:23928.625
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24386.0
# BTC Price:23068.625
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24940.5
# BTC Price:23623.125
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 25536.25
# BTC Price:24218.875
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 25515.0
# BTC Price:24197.625
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 25306.75
# BTC Price:23989.375
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 25254.0
# BTC Price:23936.625
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24601.75
# BTC Price:23284.375
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 24672.25
# BTC Price:23354.875
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 22658.0
# BTC Price:21340.625
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 22365.25
# BTC Price:21047.875
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 22830.0
# BTC Price:21512.625
# [None]
# USD balance: 1317.375
# BTC balance: 1
# Account Value: 23038.25
# BTC Price:21720.875
# change in sentiment
# Signal.SELL
# [<Signal.SELL: 2>]
# 2022-08-25
# Signal.SELL @ 21607.375
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 22924.75
# BTC Price:21607.375
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 23871.5
# BTC Price:20660.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24434.25
# BTC Price:20097.875
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24576.0
# BTC Price:19956.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24298.5
# BTC Price:20233.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24655.5
# BTC Price:19876.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24612.0
# BTC Price:19920.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24820.25
# BTC Price:19711.875
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25711.0
# BTC Price:18821.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25528.5
# BTC Price:19003.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25174.25
# BTC Price:19357.875
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 23221.0
# BTC Price:21311.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 22101.25
# BTC Price:22430.875
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24242.0
# BTC Price:20290.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24569.25
# BTC Price:19962.875
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24737.25
# BTC Price:19794.875
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24909.25
# BTC Price:19622.875
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25013.0
# BTC Price:19519.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25535.5
# BTC Price:18996.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25510.0
# BTC Price:19022.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25229.5
# BTC Price:19302.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25716.5
# BTC Price:18815.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25339.75
# BTC Price:19192.375
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25451.5
# BTC Price:19080.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24988.5
# BTC Price:19543.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25123.0
# BTC Price:19409.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25041.5
# BTC Price:19490.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24995.5
# BTC Price:19536.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24306.0
# BTC Price:20226.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24412.5
# BTC Price:20119.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24516.0
# BTC Price:20016.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25070.0
# BTC Price:19462.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25317.75
# BTC Price:19214.375
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25507.25
# BTC Price:19024.875
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25389.0
# BTC Price:19143.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25155.75
# BTC Price:19376.375
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25365.75
# BTC Price:19166.375
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25003.75
# BTC Price:19528.375
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25318.75
# BTC Price:19213.375
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25300.75
# BTC Price:19231.375
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25464.0
# BTC Price:19068.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25340.5
# BTC Price:19191.625
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 25189.0
# BTC Price:19343.125
# [None]
# USD balance: 44532.125
# BTC balance: -1
# Account Value: 24259.75
# BTC Price:20272.375
# change in sentiment
# Signal.BUY
# [<Signal.BUY: 1>]
# 2022-10-26
# Signal.BUY @ 20762.375
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 23769.75
# BTC Price:20762.375
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 23631.5
# BTC Price:20624.125
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 23622.75
# BTC Price:20615.375
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 23377.0
# BTC Price:20369.625
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 23454.75
# BTC Price:20447.375
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 23266.5
# BTC Price:20259.125
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 23270.5
# BTC Price:20263.125
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 24116.0
# BTC Price:21108.625
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 23813.875
# BTC Price:20806.5
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 21173.5
# BTC Price:18166.125
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 19208.25
# BTC Price:16200.875
# [None]
# USD balance: 3007.375
# BTC balance: 1
# Account Value: 21060.375
# BTC Price:18053.0
# change in sentiment
# Signal.SELL
# [<Signal.SELL: 2>]
# 2022-11-11
# Signal.SELL @ 16574.5
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19581.875
# BTC Price:16574.5
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19906.875
# BTC Price:16249.5
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19335.25
# BTC Price:16821.125
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19590.625
# BTC Price:16565.75
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19478.0
# BTC Price:16678.375
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19540.0
# BTC Price:16616.375
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 20383.25
# BTC Price:15773.125
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 20039.25
# BTC Price:16117.125
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19546.5
# BTC Price:16609.875
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19602.75
# BTC Price:16553.625
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19636.5
# BTC Price:16519.875
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19901.25
# BTC Price:16255.125
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19666.75
# BTC Price:16489.625
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19061.0
# BTC Price:17095.375
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19243.0
# BTC Price:16913.375
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19124.75
# BTC Price:17031.625
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19217.75
# BTC Price:16938.625
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19162.75
# BTC Price:16993.625
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19329.0
# BTC Price:16827.375
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 18954.875
# BTC Price:17201.5
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19050.25
# BTC Price:17106.125
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 19035.0
# BTC Price:17121.375
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 18403.75
# BTC Price:17752.625
# [None]
# USD balance: 36156.375
# BTC balance: -1
# Account Value: 18377.5
# BTC Price:17778.875
# change in sentiment
# Signal.BUY
# [<Signal.BUY: 1>]
# 2022-12-15
# Signal.BUY @ 17417.625
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 18738.75
# BTC Price:17417.625
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 18203.5
# BTC Price:16882.375
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 17920.0
# BTC Price:16598.875
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 18184.5
# BTC Price:16863.375
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 18099.5
# BTC Price:16778.375
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 18105.0
# BTC Price:16783.875
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 18127.875
# BTC Price:16806.75
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 18161.5
# BTC Price:16840.375
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 17982.0
# BTC Price:16660.875
# [None]
# USD balance: 1321.125
# BTC balance: 1
# Account Value: 17912.0
# BTC Price:16590.875
# change in sentiment
# Signal.SELL
# [<Signal.SELL: 2>]
# 2022-12-29
# Signal.SELL @ 16597.375
# USD balance: 34515.875
# BTC balance: -1
# Account Value: 17918.5
# BTC Price:16597.375
# [None]
# USD balance: 34515.875
# BTC balance: -1
# Account Value: 17960.5
# BTC Price:16555.375
# [None]
# USD balance: 34515.875
# BTC balance: -1
# Account Value: 17793.25
# BTC Price:16722.625
# [None]
# USD balance: 34515.875
# BTC balance: -1
# Account Value: 17860.0
# BTC Price:16655.875
# [None]
# USD balance: 34515.875
# BTC balance: -1
# Account Value: 17717.75
# BTC Price:16798.125
# [None]
# USD balance: 34515.875
# BTC balance: -1
# Account Value: 17638.25
# BTC Price:16877.625

# %%
S.account.log
# Out:
# {'2021-10-07': 'Signal.BUY1',
#  '2021-11-23': 'Signal.SELL1',
#  '2022-02-14': 'Signal.BUY1',
#  '2022-03-02': 'Signal.SELL1',
#  '2022-03-03': 'Signal.BUY1',
#  '2022-03-04': 'Signal.SELL1',
#  '2022-03-09': 'Signal.BUY1',
#  '2022-03-14': 'Signal.SELL1',
#  '2022-03-24': 'Signal.BUY1',
#  '2022-04-15': 'Signal.SELL1',
#  '2022-07-21': 'Signal.BUY1',
#  '2022-08-25': 'Signal.SELL1',
#  '2022-10-26': 'Signal.BUY1',
#  '2022-11-11': 'Signal.SELL1',
#  '2022-12-15': 'Signal.BUY1',
#  '2022-12-29': 'Signal.SELL1'}

# %%
# def PlotEquity(df):
fig, axs = plt.subplots(2, figsize=(15,15))
date = account.df_account['Date']
axs[0].title.set_text('Account Value')
axs[1].title.set_text('BTC Price')
axs[0].plot(date, account.df_account['Account Value'])
axs[1].plot(date, account.df_account['BTC Px'])

# %%
ib.disconnect()

# %%
"""calculate hurst exponent
H < 0.5: mean-reverting
H = 0.5: GBM
H > 0.5: trending
"""
"""https://towardsdatascience.com/introduction-to-the-hurst-exponent-with-code-in-python-4da0414ca52e#:~:text=To%20calculate%20the%20Hurst%20exponent,versus%20the%20mentioned%20standard%20deviations.
"""

# BTC - short duration - 5 min barsize setting over 7D  - appears mean reverting; half-life was 100 bars
# SPY - short duration - 5 mins over 7d - appears trending 

ib = IB()
ib.connect('127.0.0.1', 7497, 7)
# contract = Crypto('BTC', exchange='PAXOS', currency='USD')
contract = Stock('SPY', 'SMART', currency='USD')
bars = ib.reqHistoricalData(contract=contract, endDateTime='', durationStr='365 D',
                                    barSizeSetting='8 hours', whatToShow='MIDPOINT', useRTH=False)

# %%
df = pd.DataFrame({'close':[i.close for i in bars], 'date':[i.date for i in bars]})
time_series = np.array([i.close for i in bars])
df
# Out:
#        close                date
# 0    426.295 2021-06-25 04:00:00
# 1    426.885 2021-06-25 12:00:00
# 2    426.535 2021-06-28 04:00:00
# 3    427.205 2021-06-28 12:00:00
# 4    427.995 2021-06-29 04:00:00
# ..       ...                 ...
# 829  406.035 2022-12-02 11:00:00
# 830  405.945 2022-12-02 19:00:00
# 831  403.360 2022-12-05 04:00:00
# 832  400.240 2022-12-05 11:00:00
# 833  400.420 2022-12-05 19:00:00
#
# [834 rows x 2 columns]

# %%
"""get returns"""
df['returns'] = df['close'].pct_change()
returns = np.array(df['returns'].dropna())
returns[0:5]
# Out:
# array([-0.01363374, -0.01218101,  0.04000757,  0.04269911,  0.0109376 ])

# %%
def GetHurst(time_series, max_lag=5):
    lags = range(2, max_lag)
    
    #variances of lagged differences
    tau = [np.std(np.subtract(time_series[lag:], time_series[:-lag])) for lag in lags]
    
    #hurst exponent is the slope of the log plot
    regression = np.polyfit(x=np.log(lags), y=np.log(tau), deg=1)
    
    return regression[0]

# %%
max_lags = [5, 10, 30, 100, 300]
for i in max_lags:
    print(GetHurst(time_series=time_series, max_lag=i))
# Out:
# 0.5010967434731647
# 0.4991682130560413
# 0.48189360065690673
# 0.432548549816401
# 0.32952678096131766

# %%
df['close'].plot()
# Out:
# <AxesSubplot:>

# %%
max_lags = [5, 10, 30]
for i in max_lags:
    print(GetHurst(time_series=returns, max_lag=i))
# Out:
# -0.03173854596913254
# -0.012352595490179237
# -0.006478070055894387

# %%
"""testing GBM, trending, and mean reverting"""
sample_size = 1000
scalar = 100

np.random.seed(123)
df_test_data = pd.DataFrame(data={"mean_rev": np.log(np.random.randn(sample_size) + scalar),
                        "gbm": np.log(np.cumsum(np.random.randn(sample_size)) + scalar),
                        "trending": np.log(np.cumsum(np.random.randn(sample_size) + 1) + scalar)})

# %%
"""calculate half life"""
lag = 5
# df = pd.DataFrame({'close': df_test_data['mean_rev']})

# %%
df['lag'] = df['close'].shift(periods=lag)

# %%
df.dropna(inplace = True)
# df.head(10)
# df.tail(20)
X = df['lag']
Y = df['close'] - df['lag']
X = sm.add_constant(X)

# %%
model = sm.OLS(Y,X)
results = model.fit()
results.params
print(results.t_test([1,0]))
# Out:
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            12.6648      3.726      3.399      0.001       5.351      19.979
# ==============================================================================

# %%
results.pvalues
# Out:
# const    0.000709
# lag      0.000596
# dtype: float64

# %%
slope = results.params['lag']

# %%
half_life = -math.log(2)/slope
half_life
# Out:
# 23.115004958980904

# %%
df_ols = pd.DataFrame({'Y': Y, 'X': X['lag']})
df_ols.plot(x='X',y='Y')
plt.scatter(df_ols['X'], df_ols['Y'])

# %%
"""program sequence
1) pick markets - SPY, BTC, commodities, rates, etc
2) determine if trending, mean-reverting, or gbm
 - should focus on longer time intervals to reduce the amount of trades
3) determine indicators for each regime
a) if mean-reverting, calculate half-life for look back window
   - mean-reverting signals?
b) if trending, trending signals ?
 
-

"""

# %%
"""momentum"""

# %%
"""mean reverting"""
def LinearMeanReverting(look_back):
    #lookback can be set to the half-life
    pass

def BuyonGap():
    #buy stocks which gap > 1 std dev below prev day's close
    #only buy those whose opening px is above 20dma of closing prices
    #can do the opposite strategy as well - sellongap
    pass
    
def VIXSandP():
    pass

# %%
array = np.array([10, 11, 11.5, 10.75, 12, 11.75, 12.25, 14, 16, 17, 15.6, 15.75, 16, 14, 16.5, 17, 17.25, 18, 18.75,20])
period = 5
smoothing = 2
k = smoothing / (1 + period)
EMA = np.array([])
EMA = np.append(EMA,array[0:period].sum()/period)

for i in range(period,len(array)):
    new_value = array[i] * k  + EMA[-1] * (1 - k)
    EMA = np.append(EMA, new_value)

# %%
array[0:period]
# Out:
# array([10.  , 11.  , 11.5 , 10.75, 12.  ])

# %%
sum([4,3,5])
# Out:
# 12
