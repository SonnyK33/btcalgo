# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from math import sqrt
import pandas_ta as ta
from arch import arch_model
import numpy as np
from ib_insync import *
from collections import deque
from enum import Enum
import datetime
import logging
import math
util.startLoop()

# %%
"""start here
TODO's:
1) get list of simple trending strategies (have MA, finish EMA, maybe couple more) -> Done
2) combine them? or just use one? look at the Carver example on Github -> for now, just use EMA
3) Why isn't plot equity curve working? think bc dataframe is only getting columns for relevant asset
after a trade is requested
4) Sketch out architecture w/ class diagrams and objects. Account, strategy, contracts, etc. Last time
I was working on backtesting and displaying a dataframe showing full record of transactions. Think I 
should spend some upfront time thinking about architecture. 


5) Finish AddSignalPlot fn.
6) Functionality to generate plots in abstract way for different strategies.
7) back to actual trading - how to run for >1 contracts? may require multiple threads
8) run live (paper trading) in cloud 
9) Strategies should be objects not just parameters, would make it easier to set multiple strategies at once
including the same strategy (eg EMA) with multiple parameters so could track momentum over various scales simultaneously
6) annotate charts



"""

# %%
"""logging parameters"""
today = datetime.datetime.today().date()
logging.basicConfig(level = logging.INFO,
                   filename = 'algo_log_'+str(today)+'_.log',
                   filemode='w')

# %%
contract_dict = {'Stock':Stock, 'Crypto':Crypto}

class Algo():
    def __init__(self, client, addr, port, client_id):
        self.client = client
        self.addr = addr
        self.port = port
        self.client_id = client_id
        
        self.client.connect(addr, port, client_id)
        
    def SetPaperBalances(self):
        self.USD_balance = 1000
        self.BTC_balance = 0
        
        print('USD balance: {}'.format(self.USD_balance))
        print('BTC balance: {}'.format(self.BTC_balance))
    
    def GetContract(self, contract_type, ticker, exchange, currency):
        return contract_dict[contract_type](ticker, exchange, currency)
    
    def GetHistoricalData(self, contract, duration='1 D', bar_size='1 hour'):
        bars = ib.reqHistoricalData(contract=contract, endDateTime='', durationStr=duration,
                                    barSizeSetting=bar_size, whatToShow='MIDPOINT', useRTH=True)
        return bars
    
    def BuildEMA(self, slow_period, fast_period):
        """using deques instead of dataframes"""
        self.slow_ema = deque(maxlen=slow_period)
        self.fast_ema = deque(maxlen=fast_period)
        
        """need to employ scanner to pull in data"""
        
           
    def GetDMI(self, df):
        df_adx = ta.adx(high=df['high'], low=df['low'], close=df['close'])
        df['ADX'] = df_adx['ADX_14']
        df['DMN'] = df_adx['DMN_14']
        df['DMP'] = df_adx['DMP_14']
        df['DM_diff'] = df['DMP'] > df['DMN']
        return df
        
    
    
    def GetMovingAverages(self, df, low, high, plot=True):
#         print('length:', len(df))
        df_MA = df.copy()
        if len(df) < high:
            return
#         display('in mov avg fn', df_MA)
        
        df_MA[str(low)+'_average'] = df.close.rolling(low).mean()
        df_MA[str(high)+'_average'] = df.close.rolling(high).mean()
#         df_MA.dropna(inplace=True)
        df_MA['MA_diff'] = df_MA[str(high)+'_average'] > df_MA[str(low)+'_average']
        
        if plot:
            df_MA['close'].plot(legend=True)
            df_MA[str(low)+'_average'].plot(legend=True)
            df_MA[str(high)+'_average'].plot(legend=True)
        
#         display('end of mov avg', df_MA)
        return df_MA
    
    
    def PlacePaperOrder(self, order_type, price=None, quantity=None, date=None):
        print('placing order:', order_type)

        if order_type=='sell':
            print(date)
            print('{} @ {}'.format(order_type, price))
            self.BTC_balance -= quantity
            self.USD_balance += quantity * price
            

        elif order_type=='buy':
            print(date)
            print('{} @ {}'.format(order_type, price))
            self.BTC_balance += quantity
            self.USD_balance -= quantity * price

        else:
            return 


        print('USD balance: {}'.format(self.USD_balance))
        print('BTC balance: {}'.format(self.BTC_balance))
        account_balance = self.USD_balance + self.BTC_balance * price
        print('Account balance: {}\n'.format(account_balance))       

    def RunDMI(self, df, ADX_MIN=20):
        for count, row in enumerate(df.iterrows()):
            if count==0:
                sentiment = row[1]['DM_diff']
            else:
                if (row[1]['ADX'] >= ADX_MIN):
                    if row[1]['DM_diff'] == sentiment:
                        self.PlacePaperOrder('no change')
                    else:
                        if row[1]['DM_diff']:
                            self.PlacePaperOrder('buy',row[1]['close'],1, row[1]['date'])
                        else:
                            self.PlacePaperOrder('sell', row[1]['close'],1, row[1]['date'])
                    sentiment = row[1]['DM_diff']
                else: continue                                     
                        
    
    def RunStrategy(self, df):   

        for count, row in enumerate(df.iterrows()):
            if count==0:
                sentiment = row[1]['MA_diff']
            else:
                if row[1]['MA_diff'] == sentiment:
                    self.PlacePaperOrder('no change')
                else:
                    if row[1]['MA_diff']:
                        self.PlacePaperOrder('sell',row[1]['close'],1)
                    else:
                        self.PlacePaperOrder('buy', row[1]['close'],1)
                    sentiment = row[1]['MA_diff']


def Main(client_id):
    
    ib = IB()
    algo = Algo(ib, '127.0.0.1', 7497, client_id=client_id)
    
    contract = algo.GetContract('Crypto','BTC', 'PAXOS', 'USD')
    
    bars = algo.GetHistoricalData(contract, '180 D', '1 day')
    
    df = util.df(bars)
    
    algo.SetPaperBalances()
    
#     df_MA =  algo.GetMovingAverages(df, 10, 30, True)
    df_DMI = algo.GetDMI(df)
    
#     algo.RunStrategy(df_MA)
    algo.RunDMI(df_DMI)
    
    print('USD balance: {}'.format(algo.USD_balance))
    print('BTC balance: {}'.format(algo.BTC_balance))

    account_value = algo.USD_balance + algo.BTC_balance * bars[-1].close
    print('Account value: {}'.format(account_value))

# %%
class Account():
    def __init__(self, USD_balance: int, BTC_balance: int, BTC_price: float = None):
        self.USD_balance = USD_balance
        self.BTC_balance = BTC_balance
        self.BTC_price = BTC_price                 
#         self.df_account = pd.DataFrame(columns=['Date', 'USD', 'BTC', 'Account Value', 'BTC Px'])
        self.df_account = pd.DataFrame(columns=['Date', 'USD', 'Account Value'])
        self.log = dict()
        self.contracts = dict() #{contract: quantity}
    
    
#        row_dict = self.contracts.copy()
        
#         total = self.USD_balance
#         for contract, quantities in self.contracts.items():
#             total += quantities * 5
        
     
    
    
    def __call__(self):
        return self.returnBalance()
        
    def __repr__(self):
        return 'USD balance: '+ str(self.USD_balance) + '\nBTC balance: ' + str(self.BTC_balance) + '\nAccount Value: '+str(self.USD_balance + self.BTC_balance * self.BTC_price) + '\nBTC Price:' + str(self.BTC_price)
        
        
    def updateBTCPrice(self, BTC_price: float):
        self.BTC_price = BTC_price
        
    def closePosition(self):
        self.BTC_balance = 0
        self.USD_balance -= self.BTC_balance * self.BTC_price
        
    def trade(self, contract, signal: Signal, quantity: int, date: datetime, price): #-> order:    
        print('trading '+contract.symbol)
        self.log[str(date)] = str(signal) + str(quantity)
#         logging.info("%s, %s @, %s" %(signal, quantity))
        
        #get last price for contract
#         self.price = 5
        
        if contract.symbol not in self.contracts.keys():
            self.contracts[contract.symbol] = 0
            self.df_account[contract.symbol] = ''
            self.df_account[contract.symbol+' Px'] = np.nan
            
        
        #exit current position if there is one 
        else:
            self.USD_balance += self.contracts[contract.symbol] * price
            self.contracts[contract.symbol] = 0
            
        direction = 1 if signal==Signal.BUY else -1
        
        self.contracts[contract.symbol] += direction * quantity
        self.USD_balance -= direction * quantity * price
        
        order_type = 'BUY' if signal==Signal.BUY else 'SELL'
        
        order = LimitOrder(order_type, quantity, round(price, 0),
                           tif='GTC')
        return order     
        
        
        
    
    def tradeBTC(self, signal: Signal, quantity: int, date: datetime): #-> order:
        
        self.log[str(date)] = str(signal) + str(quantity)
        logging.info("%s, %s @, %s" %(signal, quantity, self.BTC_price))
        
        #first exit current position if there is one 
        if self.BTC_balance != 0:
            self.USD_balance += self.BTC_balance * self.BTC_price
            self.BTC_balance = 0
        
        direction = 1 if signal==Signal.BUY else -1
        
        self.BTC_balance += direction * quantity
        self.USD_balance -= direction * quantity * self.BTC_price
        
        order_type = 'BUY' if signal==Signal.BUY else 'SELL'
        
        order = LimitOrder(order_type, quantity, round(self.BTC_price, 0),
                           tif='GTC')
        return order 
        
#         self.updateBalance([date, self.USD_balance, self.BTC_balance, self.total])
                
    def updateBalance(self, date, close):
        #get prices, add price function
        row_dict = self.contracts.copy()
        
        total = self.USD_balance
        for ticker, quantities in self.contracts.items():
            price = close
            total += quantities * close
            row_dict[ticker+' Px'] = close
        
        row_dict['Account Value'] = total
        row_dict['Date'] = date
        row_dict['USD'] = self.USD_balance               
        
        self.df_account = self.df_account.append(row_dict, ignore_index=True)
#         display(self.df_account)
        
        
        
        
                    

    #         total = self.USD_balance + self.BTC_balance * self.price

        # add row
        
        

#         self.df_account.loc[len(self.df_account.index)] = [date, self.USD_balance,
#                                                           self.BTC_balance, total, self.BTC_price]       
        
        
        
        
#         total = self.USD_balance + self.BTC_balance * self.BTC_price
#         self.df_account.loc[len(self.df_account.index)] = [date, self.USD_balance,
#                                                           self.BTC_balance, total, self.BTC_price]       
        
    def returnBalance(self):
        return self.df_account
    
    def plotBalance(self):
        self.df_account.plot(x='Date', y=['Account Value'])

# %%
"""real time updates"""

from collections import deque
import pandas as pd


Sentiment = Enum('Sentiment','BEAR NEUTRAL BULL')
Signal = Enum('Signal','BUY SELL')

strategy_dict = dict()

def AddStrategy(strategy_fn):
    strategy_dict[strategy_fn.__name__] = strategy_fn
    return strategy_fn
  
def LogFunctionCall(fn):
    logging.info(fn.__name__+' called')
    return fn

def PrintFunction(fn):
    print(fn)
#     print(fn.__code__.co_varnames)
    return fn
    

class Strategy():
    def __init__(self, account: Account, ib, client_id: int, contract: Contract,
                 paper_trading: bool = True):
        self.client_id = client_id
        self.ib = ib     
        self.algo = Algo(ib, '127.0.0.1', 7497, client_id=self.client_id)
        self.algo.SetPaperBalances()
        self.contract = contract
#         self.contract = Crypto('BTC', exchange='PAXOS', currency='USD')
        self.account = account
        self.paper_trading=paper_trading
        self.sentiment = dict()
        self.signal = dict()
        self.trades = list()


    
    def onBarUpdate(self, bars, newBar):
        if newBar:
            print('on bar update', bars[-1])
            self.strategy_params['close'] = bars[-1].close 
            self.strategy(**self.strategy_params)    
            self.SignalProcess(self.strategy.__name__, date=bars[-1].time)   
 
    
    def SetSentiment(self, current_sentiment):                 
        print('set sentiment')
        if self.sentiment.get(self.strategy.__name__) is None:
            self.sentiment[self.strategy.__name__] = current_sentiment
            print('first sentiment')
            return

        if self.sentiment[self.strategy.__name__] != current_sentiment:
            print('change in sentiment')
            
            if current_sentiment == Sentiment.BEAR:
                self.signal[self.strategy.__name__] = Signal.SELL               

            elif current_sentiment == Sentiment.BULL:
                self.signal[self.strategy.__name__] = Signal.BUY                        
        else:
            print('no change in sentiment')

                              
        self.sentiment[self.strategy.__name__] = current_sentiment
#         print('ending sentiment:', self.sentiment['EMAverage'])
        
    
    def AddSignalPlot(self):
        for signal, value_array in self.signal_dict.items():
            missing = len(self.account.df_account) - len(value_array)
            value_array = np.insert(value_array, 0, [0]*missing)            
            self.df_plot = S.account.df_account.copy()
            self.df_plot[signal] = value_array
            self.df_plot.dropna(inplace=True)                     
                            
    @AddStrategy
    @LogFunctionCall
    def EMAverage(self, smoothing, period, close):
        if not hasattr(self, "SMA_lst"):
            self.SMA_lst = []
        
        self.SMA_lst.append(close)        
        self.account.updateBTCPrice(BTC_price=close)        
        
        if len(self.SMA_lst) < period:            
            return            
        
        k = smoothing / (1 + period)
        
        if len(self.SMA_lst) == period:            
#             self.EMA = np.array([])
#             self.EMA = np.append(self.EMA,sum(self.SMA_lst[0:period])/period)
            
            self.signal_dict['EMA'] = np.array([])
            self.signal_dict['EMA'] = np.append(self.signal_dict['EMA'],
                                                sum(self.SMA_lst[0:period])/period)
            
            return
        
        new_value = close * k  + self.EMA[-1] * (1 - k)
        self.EMA = np.append(self.EMA, new_value)
        print(self.EMA)
        
                
        print('last value:', self.EMA[-1])
        print('close', close)
        if close < self.EMA[-1]:            
            current_sentiment_EMA = Sentiment.BEAR
            print('bearish')
        elif close > self.EMA[-1]:
            current_sentiment_EMA = Sentiment.BULL
            print('bullish')
        else:
            current_sentiment_EMA = Sentiment.NEUTRAL   
            
        
        self.SetSentiment(current_sentiment_EMA)                       

    
    @AddStrategy
    @LogFunctionCall
    def MovingAverage(self, low, high, close):
        """should be an abstract class"""
        if not (hasattr(self, "low_deque") and hasattr(self, "high_deque")):
            low_deque_len, high_deque_len = low, high
            self.low_deque = deque(maxlen=low_deque_len)
            self.high_deque = deque(maxlen=high_deque_len)
            self.low_avg, self.high_avg = np.array([]), np.array([])

                        
            
        self.low_deque.append(close)
        self.high_deque.append(close)
        self.account.updateBTCPrice(BTC_price=close)        
        
        if len(self.high_deque) < self.high_deque.maxlen:
            return
        low_avg = sum(self.low_deque)/len(self.low_deque)
#         self.low_avg.append(low_avg)
        self.low_avg = np.append(self.low_avg,low_avg)
        high_avg = sum(self.high_deque)/len(self.high_deque)
#         self.high_avg.append(high_avg)
        self.high_avg = np.append(self.high_avg,high_avg)

        if low_avg < high_avg:
            current_sentiment_MA = Sentiment.BEAR
        elif low_avg > high_avg:
            current_sentiment_MA = Sentiment.BULL
        else:
            current_sentiment_MA = Sentiment.NEUTRAL     
            
        self.SetSentiment(current_sentiment_MA) 
     
        
    @LogFunctionCall
    @PrintFunction
    def SignalProcess(self, *signals, date, close):        
        print('signal dict',self.signal.items())
        signal_list = [values for keys,values in self.signal.items() if keys in signals]
        print('signals', signal_list)        
        
        if len(set(signal_list))==1 and signal_list[0] is not None: #i.e. all signals are the same
            print(date)
            signal = signal_list[0]
            print(str(signal) + ' @ ' + str(self.account.BTC_price))
            order = self.account.trade(self.contract, signal=signal, quantity=1, date=date,
                                       price=close)
            
            if not self.paper_trading:
                self.trades.append(self.ib.placeOrder(self.contract, order))
            
            self.ClearSignals(*signals)                
        
        self.account.updateBalance(date=date, close=close)
        print(self.account)
    
    def ClearSignals(self, *signals):
        for s in signals:
            self.signal[s]=None                  

    def SetStrategy(self, strategy, **kwargs):
        self.strategy = strategy_dict[strategy]
        self.strategy_params = kwargs
        self.strategy_params['self'] = self
        
            
    def RunStrategy(self):             

        bars = ib.reqRealTimeBars(contract=self.contract,
                                  barSize=5,
                                  whatToShow='MIDPOINT',
                                 useRTH=False)
        bars.updateEvent += self.onBarUpdate

        self.ib.sleep(100)
        self.ib.cancelRealTimeBars(bars)        
    
        
    def Backtest(self, duration='360 D', barSize='1 day'):
        self.paper_trading = True
#         display(self.contract)
#         display(self.contract.__dict__)
        bars = ib.reqHistoricalData(
            self.contract, endDateTime='', durationStr=duration,
            barSizeSetting=barSize, whatToShow='MIDPOINT', useRTH=True)     
        
#         display(bars)
        df = util.df(bars)        
#         display(df)
        for row in df.itertuples(name='bar', index=False):    
            self.strategy_params['close'] = row.close 
            self.strategy(**self.strategy_params)    
            self.SignalProcess(self.strategy.__name__, date=row.date, close=row.close)
            
    def PlotEquityCurve(self, contract_ticker):
        df_plot = self.account.df_account.copy()
        df_plot.dropna(inplace=True)
        fig, axs = plt.subplots(2, figsize=(15,15))        
        date = df_plot['Date']
        axs[0].title.set_text('Account Value')
        axs[1].title.set_text(contract_ticker)
        axs[0].plot(date, df_plot['Account Value'])
        axs[1].plot(date, df_plot[contract_ticker+' Px'])
        plt.show()
        
    def PlotSignal(self, signal_values):
        plt.figure(figsize=(15,15)) 
        self.account.df_account['Signal'] = signal_values
        plt.plot(self.account.df_account['Date'], self.account.df_account['Signal'])
        plt.plot(self.account.df_account['Date'], self.account.df_account['BTC Px'])
# Out:
# <function Strategy.SignalProcess at 0x000001C291FC9AF0>

# %%
# # contract = Forex('USDCAD')
# # contract = CMDTY('GOLD')
# # contract = Bond(secIdType='ISIN', secId='US594918CE21')
# # contract = Stock('INTC')

# # contract = Stock('INTC', 'SMART', 'USD', primaryExchange='IEX')
# # contract = Stock('TSLA', 'SMART', 'USD')
# # ib.reqHeadTimeStamp(contract, whatToShow='TRADES', useRTH=True)
# # contract = Stock('SPY', 'SMART', 'USD')
# # contract = Stock('INTC', 'SMART', 'USD', primaryExchange='ISLAND')
# contract = Future('NQ', '20230317', 'CME')
# ib2 = IB()
# ib2.connect('127.0.0.1', 7497, 13)

# bars = ib2.reqHistoricalData(
#         contract,
#         endDateTime='',
#         durationStr='30 D',
#         barSizeSetting='1 day',
#         whatToShow='MIDPOINT',
#         useRTH=True,
#     formatDate=1)

# %%
# print(contract)
# bars

# %%
"""all setting of sentiment done here
        calclates the trading signals and sends that to strategy
        
        use above algo class
        
        """

class Algorithm():
    def __init__(self, indicator: str, contract: Contract):
        pass

# %%
ib = IB()

# contract1 = Crypto('BTC', exchange='PAXOS', currency='USD')
# contract2 = Stock('MSFT', 'SMART', 'USD')
# contract2 = Stock('INTC', 'SMART', 'USD', primaryExchange='NASDAQ')
contract = Forex('EURUSD')
contract = Future('NQ', '20230317', 'CME')
contract = Future('ES', '20230317', 'CME')
account = Account(USD_balance=1000, BTC_balance=0)
S = Strategy(account, ib, 8, contract=contract, paper_trading=True)

S.SetStrategy('MovingAverage',low=5,high=10)
# S.SetStrategy('EMAverage',smoothing=2, period=20)


# S.RunStrategy()
    
S.Backtest(duration='360 D')
# Out:
# USD balance: 1000
# BTC balance: 0
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4709.5
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4622.5
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4642.25
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4276.5
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4462.5
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4539.5
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4561.0
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4485.0
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4171.25
# set sentiment
# first sentiment
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4473.5
# set sentiment
# no change in sentiment
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4449.25
# set sentiment
# no change in sentiment
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4513.5
# set sentiment
# no change in sentiment
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:4475.875
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-03-24
# Signal.BUY @ 4522.375
# trading ES
# USD balance: -3522.375
# BTC balance: 0
# Account Value: -3522.375
# BTC Price:4522.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3522.375
# BTC balance: 0
# Account Value: -3522.375
# BTC Price:4548.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3522.375
# BTC balance: 0
# Account Value: -3522.375
# BTC Price:4249.5
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-03-29
# Signal.SELL @ 4253.5
# trading ES
# USD balance: 4984.625
# BTC balance: 0
# Account Value: 4984.625
# BTC Price:4253.5
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-04-04
# Signal.BUY @ 4604.125
# trading ES
# USD balance: -4223.625
# BTC balance: 0
# Account Value: -4223.625
# BTC Price:4604.125
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-04-06
# Signal.SELL @ 4504.125
# trading ES
# USD balance: 4784.625
# BTC balance: 0
# Account Value: 4784.625
# BTC Price:4504.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4784.625
# BTC balance: 0
# Account Value: 4784.625
# BTC Price:4530.875
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-04-08
# Signal.BUY @ 4527.25
# trading ES
# USD balance: -4269.875
# BTC balance: 0
# Account Value: -4269.875
# BTC Price:4527.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4269.875
# BTC balance: 0
# Account Value: -4269.875
# BTC Price:4442.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4269.875
# BTC balance: 0
# Account Value: -4269.875
# BTC Price:4414.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4269.875
# BTC balance: 0
# Account Value: -4269.875
# BTC Price:4469.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4269.875
# BTC balance: 0
# Account Value: -4269.875
# BTC Price:4433.125
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-04-18
# Signal.SELL @ 4437.625
# trading ES
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4437.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4482.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4501.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4433.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4306.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4349.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4255.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4255.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4255.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4255.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4182.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4182.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4182.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4182.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4182.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4167.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4075.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4075.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3946.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4041.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4025.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4117.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3953.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3934.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3844.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:4004.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3950.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3900.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3915.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3975.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4605.375
# BTC balance: 0
# Account Value: 4605.375
# BTC Price:3955.0
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-06-01
# Signal.BUY @ 4138.875
# trading ES
# USD balance: -3672.375
# BTC balance: 0
# Account Value: -3672.375
# BTC Price:4138.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3672.375
# BTC balance: 0
# Account Value: -3672.375
# BTC Price:4194.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3672.375
# BTC balance: 0
# Account Value: -3672.375
# BTC Price:3965.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3672.375
# BTC balance: 0
# Account Value: -3672.375
# BTC Price:4065.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3672.375
# BTC balance: 0
# Account Value: -3672.375
# BTC Price:4185.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3672.375
# BTC balance: 0
# Account Value: -3672.375
# BTC Price:4065.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3672.375
# BTC balance: 0
# Account Value: -3672.375
# BTC Price:4004.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3672.375
# BTC balance: 0
# Account Value: -3672.375
# BTC Price:4075.0
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-06-13
# Signal.SELL @ 3965.0
# trading ES
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3965.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3965.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3965.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3710.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3938.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3781.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3797.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:4027.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3851.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.625
# BTC balance: 0
# Account Value: 4257.625
# BTC Price:3959.375
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-06-28
# Signal.BUY @ 3863.625
# trading ES
# USD balance: -3469.625
# BTC balance: 0
# Account Value: -3469.625
# BTC Price:3863.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3469.625
# BTC balance: 0
# Account Value: -3469.625
# BTC Price:3870.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3469.625
# BTC balance: 0
# Account Value: -3469.625
# BTC Price:3817.625
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-07-01
# Signal.SELL @ 3863.5
# trading ES
# USD balance: 4257.375
# BTC balance: 0
# Account Value: 4257.375
# BTC Price:3863.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.375
# BTC balance: 0
# Account Value: 4257.375
# BTC Price:3970.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.375
# BTC balance: 0
# Account Value: 4257.375
# BTC Price:3888.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4257.375
# BTC balance: 0
# Account Value: 4257.375
# BTC Price:3927.5
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-07-08
# Signal.BUY @ 3785.875
# trading ES
# USD balance: -3314.375
# BTC balance: 0
# Account Value: -3314.375
# BTC Price:3785.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3314.375
# BTC balance: 0
# Account Value: -3314.375
# BTC Price:3922.5
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-07-12
# Signal.SELL @ 3802.875
# trading ES
# USD balance: 4291.375
# BTC balance: 0
# Account Value: 4291.375
# BTC Price:3802.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4291.375
# BTC balance: 0
# Account Value: 4291.375
# BTC Price:3775.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4291.375
# BTC balance: 0
# Account Value: 4291.375
# BTC Price:3804.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4291.375
# BTC balance: 0
# Account Value: 4291.375
# BTC Price:3919.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4291.375
# BTC balance: 0
# Account Value: 4291.375
# BTC Price:3896.0
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-07-19
# Signal.BUY @ 3985.875
# trading ES
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:3985.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4039.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4015.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4015.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4042.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4015.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4074.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4116.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4173.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4127.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4119.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4135.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4132.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4132.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4132.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4181.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4230.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4250.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4303.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4347.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4359.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4348.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4342.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4275.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3680.375
# BTC balance: 0
# Account Value: -3680.375
# BTC Price:4225.5
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-08-23
# Signal.SELL @ 4172.625
# trading ES
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4172.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4168.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4241.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4069.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4079.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4030.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4005.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4017.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:3963.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:3953.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4023.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4006.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4664.875
# BTC balance: 0
# Account Value: 4664.875
# BTC Price:4081.0
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-09-12
# Signal.BUY @ 4159.0
# trading ES
# USD balance: -3653.125
# BTC balance: 0
# Account Value: -3653.125
# BTC Price:4159.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3653.125
# BTC balance: 0
# Account Value: -3653.125
# BTC Price:3978.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3653.125
# BTC balance: 0
# Account Value: -3653.125
# BTC Price:4009.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3653.125
# BTC balance: 0
# Account Value: -3653.125
# BTC Price:3934.75
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-09-16
# Signal.SELL @ 3930.75
# trading ES
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3930.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3953.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3908.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3825.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3803.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3739.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3694.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3692.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3757.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3685.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3631.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3722.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 4208.375
# BTC balance: 0
# Account Value: 4208.375
# BTC Price:3832.375
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-10-05
# Signal.BUY @ 3825.0
# trading ES
# USD balance: -3441.625
# BTC balance: 0
# Account Value: -3441.625
# BTC Price:3825.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3441.625
# BTC balance: 0
# Account Value: -3441.625
# BTC Price:3780.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3441.625
# BTC balance: 0
# Account Value: -3441.625
# BTC Price:3679.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3441.625
# BTC balance: 0
# Account Value: -3441.625
# BTC Price:3655.5
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-10-11
# Signal.SELL @ 3635.5
# trading ES
# USD balance: 3829.375
# BTC balance: 0
# Account Value: 3829.375
# BTC Price:3635.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3829.375
# BTC balance: 0
# Account Value: 3829.375
# BTC Price:3620.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3829.375
# BTC balance: 0
# Account Value: 3829.375
# BTC Price:3710.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3829.375
# BTC balance: 0
# Account Value: 3829.375
# BTC Price:3626.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3829.375
# BTC balance: 0
# Account Value: 3829.375
# BTC Price:3729.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3829.375
# BTC balance: 0
# Account Value: 3829.375
# BTC Price:3788.75
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-10-19
# Signal.BUY @ 3741.125
# trading ES
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3741.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3707.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3802.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3836.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3885.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3885.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3821.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3955.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3916.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3894.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3798.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -3652.875
# BTC balance: 0
# Account Value: -3652.875
# BTC Price:3756.5
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-11-04
# Signal.SELL @ 3803.375
# trading ES
# USD balance: 3953.875
# BTC balance: 0
# Account Value: 3953.875
# BTC Price:3803.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3953.875
# BTC balance: 0
# Account Value: 3953.875
# BTC Price:3843.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3953.875
# BTC balance: 0
# Account Value: 3953.875
# BTC Price:3864.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3953.875
# BTC balance: 0
# Account Value: 3953.875
# BTC Price:3787.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3953.875
# BTC balance: 0
# Account Value: 3953.875
# BTC Price:4006.375
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2022-11-11
# Signal.BUY @ 4032.375
# trading ES
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4032.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4007.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4028.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4007.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:3993.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4005.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:3990.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4043.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4073.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4068.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4004.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:3995.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4127.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4112.0
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4100.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:4038.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4110.875
# BTC balance: 0
# Account Value: -4110.875
# BTC Price:3976.375
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2022-12-07
# Signal.SELL @ 3965.75
# trading ES
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3965.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3995.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3964.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:4019.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:4053.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:4038.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3922.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3872.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3841.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3853.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3913.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3847.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3868.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3856.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3810.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3869.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3867.75
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3843.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3871.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: 3820.625
# BTC balance: 0
# Account Value: 3820.625
# BTC Price:3833.0
# set sentiment
# change in sentiment
# signal dict dict_items([('MovingAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2023-01-06
# Signal.BUY @ 3913.625
# trading ES
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:3913.625
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:3913.5
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:3941.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:3992.25
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:4002.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:4019.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:4009.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:3945.875
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:3920.375
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:3988.125
# set sentiment
# no change in sentiment
# signal dict dict_items([('MovingAverage', None)])
# signals [None]
# USD balance: -4006.625
# BTC balance: 0
# Account Value: -4006.625
# BTC Price:4036.875

# %%
missing = len(S.account.df_account) - len(S.EMA)
S.EMA = np.insert(S.EMA, 0, [0]*missing)

# %%
# account.plotBalance()
S.PlotEquityCurve('ES')
# S.PlotSignal(S.EMA)

# S.account.df_account.head(50)
# S.account.df_account['EURUSD'+' Px']

# %%
len(S.low_avg), len(S.high_avg), len(S.account.df_account)

missing = len(S.account.df_account) - len(S.high_avg)
S.high_avg = np.insert(S.high_avg, 0, [0]*missing)

missing = len(S.account.df_account) - len(S.low_avg)
S.low_avg = np.insert(S.low_avg, 0, [0]*missing)

df_plot = S.account.df_account.copy()
df_plot['low avg'] = S.low_avg
df_plot['high avg'] = S.high_avg
df_plot.dropna(inplace=True)

plt.figure(figsize=(15,15))
plt.plot(df_plot['Date'], df_plot['ES Px'])
plt.plot(df_plot['Date'], df_plot['low avg'])
plt.plot(df_plot['Date'], df_plot['high avg'])

# %%
S.account.log
# Out:
# {'2022-03-24': 'Signal.BUY1',
#  '2022-03-29': 'Signal.SELL1',
#  '2022-04-04': 'Signal.BUY1',
#  '2022-04-06': 'Signal.SELL1',
#  '2022-04-08': 'Signal.BUY1',
#  '2022-04-18': 'Signal.SELL1',
#  '2022-06-01': 'Signal.BUY1',
#  '2022-06-13': 'Signal.SELL1',
#  '2022-06-28': 'Signal.BUY1',
#  '2022-07-01': 'Signal.SELL1',
#  '2022-07-08': 'Signal.BUY1',
#  '2022-07-12': 'Signal.SELL1',
#  '2022-07-19': 'Signal.BUY1',
#  '2022-08-23': 'Signal.SELL1',
#  '2022-09-12': 'Signal.BUY1',
#  '2022-09-16': 'Signal.SELL1',
#  '2022-10-05': 'Signal.BUY1',
#  '2022-10-11': 'Signal.SELL1',
#  '2022-10-19': 'Signal.BUY1',
#  '2022-11-04': 'Signal.SELL1',
#  '2022-11-11': 'Signal.BUY1',
#  '2022-12-07': 'Signal.SELL1',
#  '2023-01-06': 'Signal.BUY1'}

# %%
S.EMA
df_plot = S.account.df_account.copy()
df_plot.dropna(inplace=True)
plt.figure(figsize=(15,15))
plt.plot(df_plot['Date'], df_plot['NQ Px'])
plt.plot(df_plot['Date'], df_plot['Signal'])

# plt.plot(S.account.df_account['Date'], S.account.df_account['NQ Px'])
# plt.plot(S.account.df_account['Date'], S.account.df_account['Signal'])

# %%
S.account.log
# Out:
# {'2022-06-10': 'Signal.BUY1',
#  '2022-06-16': 'Signal.SELL1',
#  '2022-07-22': 'Signal.BUY1',
#  '2022-08-31': 'Signal.SELL1',
#  '2022-10-26': 'Signal.BUY1',
#  '2022-12-16': 'Signal.SELL1',
#  '2023-01-17': 'Signal.BUY1'}

# %%
df_plot.head(50)
# Out:
#           Date      USD Account Value  NQ      NQ Px        Signal
# 23  2022-07-19 -11261.4          1000   1  12261.375  12207.294330
# 24  2022-07-20 -11261.4       1350.12   1  12611.500  12245.790108
# 25  2022-07-21 -11261.4       1478.88   1  12740.250  12292.881526
# 26  2022-07-22 -11261.4       1363.62   1  12625.000  12324.511857
# 27  2022-07-25  12888.6       813.625  -1  12075.000  12300.748823
# 28  2022-07-26  12888.6       838.625  -1  12050.000  12276.867983
# 29  2022-07-27 -12525.6         181.5   1  12707.125  12317.844842
# 30  2022-07-28 -12525.6         524.5   1  13050.125  12387.585809
# 31  2022-07-29 -12525.6        614.25   1  13139.875  12459.232399
# 32  2022-08-01 -12525.6       581.375   1  13107.000  12520.924551
# 33  2022-08-02 -12525.6           525   1  13050.625  12571.372213
# 34  2022-08-03 -12525.6       849.125   1  13374.750  12647.884383
# 35  2022-08-04 -12525.6         164.5   1  12690.125  12651.907299
# 36  2022-08-05 -12525.6        855.25   1  13380.875  12721.332794
# 37  2022-08-08 -12525.6       864.375   1  13390.000  12785.015385
# 38  2022-08-09  12374.4       -75.625  -1  12450.000  12753.109158
# 39  2022-08-10 -14767.6      -1196.62   1  13571.000  12831.003524
# 40  2022-08-11  10817.9      -1974.88  -1  12792.750  12827.360331
# 41  2022-08-12 -16594.9       -2888.5   1  13706.375  12911.076014
# 42  2022-08-15  9004.12      -3795.38  -1  12799.500  12900.449727
# 43  2022-08-16 -17894.9      -4445.38   1  13449.500  12952.740229
# 44  2022-08-17 -17894.9      -4445.38   1  13449.500  13000.050684
# 45  2022-08-18 -17894.9      -4171.62   1  13723.250  13068.926809
# 46  2022-08-19 -17894.9      -4435.38   1  13459.500  13106.124256
# 47  2022-08-22 -17894.9      -4479.75   1  13415.125  13135.552898
# 48  2022-08-23 -17894.9      -4526.38   1  13368.500  13157.738336
# 49  2022-08-24  8403.12      -4745.88  -1  13149.000  13156.906114
# 50  2022-08-25 -18193.9      -4895.38   1  13298.500  13170.391246
# 51  2022-08-26  7016.12      -5588.88  -1  12605.000  13116.544460
# 52  2022-08-29  7016.12      -5648.25  -1  12664.375  13073.480702
# 53  2022-08-30  7016.12         -5519  -1  12535.125  13022.208731
# 54  2022-08-31  7016.12      -5667.25  -1  12683.375  12989.938852
# 55  2022-09-01  7016.12      -5234.38  -1  12250.500  12919.516104
# 56  2022-09-02  7016.12       -5287.5  -1  12303.625  12860.859808
# 57  2022-09-06  7016.12         -5252  -1  12268.125  12804.408874
# 58  2022-09-07  7016.12      -5356.88  -1  12373.000  12763.322315
# 59  2022-09-08  7016.12      -5414.75  -1  12430.875  12731.660666
# 60  2022-09-09 -18503.9      -5743.88   1  12760.000  12734.359650
# 61  2022-09-12 -18503.9      -5573.88   1  12930.000  12752.992064
# 62  2022-09-13  6206.12      -6148.88  -1  12355.000  12715.088058
# 63  2022-09-14  6206.12      -6163.25  -1  12369.375  12682.163005
# 64  2022-09-15  6206.12      -5873.38  -1  12079.500  12624.766528
# 65  2022-09-16  6206.12      -5836.38  -1  12042.500  12569.312573
# 66  2022-09-19  6206.12      -5961.75  -1  12167.875  12531.080423
# 67  2022-09-20  6206.12      -5863.88  -1  12070.000  12487.168002
# 68  2022-09-21  6206.12      -5504.88  -1  11711.000  12413.247240
# 69  2022-09-22  6206.12      -5475.25  -1  11681.375  12343.545122
# 70  2022-09-23  6206.12      -5247.88  -1  11454.000  12258.826539
# 71  2022-09-26  6206.12      -5251.88  -1  11458.000  12182.557345
# 72  2022-09-27  6206.12      -5271.88  -1  11478.000  12115.456645

# %%
# S.account.df_account.head(50)
# df_test = S.account.df_account.copy()
# df_test.dropna(inplace=True)

# fig, axs = plt.subplots(2, figsize=(15,15))        
# date = df_test['Date']
# axs[0].title.set_text('Account Value')
# axs[1].title.set_text('EUR')
# axs[0].plot(date, df_test['Account Value'])
# axs[1].plot(date, df_test['EUR Px'])

# %%
# fig, axs = plt.subplots(2, figsize=(15,15))        
# date = S.account.df_account['Date']
# axs[0].title.set_text('Account Value')
# axs[1].title.set_text('EUR')
# axs[0].plot(date, S.account.df_account['Account Value'])
# axs[1].plot(date, S.account.df_account['EUR Px'])

# %%
# S.account.log
S.account.df_account['EUR Px'].iloc[1]
# Out:
# ''

# %%
datetime.datetime.strptime((list(S.account.log.keys())[0]), '%Y-%m-%d').date()
# Out:
# datetime.date(2021, 10, 1)

# %%
# def PlotEquity(df):
fig, axs = plt.subplots(2, figsize=(15,15))


date = account.df_account['Date']
axs[0].title.set_text('Account Value')
axs[1].title.set_text('BTC Price')
axs[0].plot(date, account.df_account['Account Value'])



# axs[1].annotate('test',xy=(10, 20000))
axs[1].plot(date, account.df_account['BTC Px'])

for d, trade in S.account.log.items():
    axs[1].annotate(trade,(mdates.date2num(datetime.datetime(d),20000)))
    
    
# axs[1].annotate('test',(mdates.date2num(datetime.datetime(2022,1,1)), 20000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-30d038e0d551> in <module>
#      14
#      15 for d, trade in S.account.log.items():
# ---> 16     axs[1].annotate(trade,(mdates.date2num(datetime.datetime(d),20000)))
#      17
#      18
#
# TypeError: an integer is required (got type str)

# %%
from matplotlib import pyplot as plt, dates as mdates
plt.plot(S.account.df_account['Date'], S.account.df_account['BTC Px'])
plt.annotate('test',(mdates.date2num(datetime.datetime(2022,1,1)), 20000))
# plt.show()


# from matplotlib import pyplot as plt, dates as mdates
# plt.rcParams["figure.figsize"] = [7.00, 3.50]
# plt.rcParams["figure.autolayout"] = True
# x = [dt.datetime(2021, 1, 1), dt.datetime(2021, 1, 2),
#    dt.datetime(2021, 1, 3), dt.datetime(2021, 1, 4)]
# y = [1, 3, 2, 5]
# fig, ax = plt.subplots()
# ax.plot_date(x, y, linestyle='-.')
# ax.annotate('Point', (mdates.date2num(x[1]), y[1]), xytext=(15, 15),
#    textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))
# fig.autofmt_xdate()
# plt.show()
# Out:
# Text(18993.0, 20000, 'test')

# %%
ib.disconnect()

# %%
"""calculate hurst exponent
H < 0.5: mean-reverting
H = 0.5: GBM
H > 0.5: trending
"""
"""https://towardsdatascience.com/introduction-to-the-hurst-exponent-with-code-in-python-4da0414ca52e#:~:text=To%20calculate%20the%20Hurst%20exponent,versus%20the%20mentioned%20standard%20deviations.
"""

# BTC - short duration - 5 min barsize setting over 7D  - appears mean reverting; half-life was 100 bars
# SPY - short duration - 5 mins over 7d - appears trending 

ib = IB()
ib.connect('127.0.0.1', 7497, 7)
# contract = Crypto('BTC', exchange='PAXOS', currency='USD')
contract = Stock('SPY', 'SMART', currency='USD')
bars = ib.reqHistoricalData(contract=contract, endDateTime='', durationStr='365 D',
                                    barSizeSetting='8 hours', whatToShow='MIDPOINT', useRTH=False)

# %%
df = pd.DataFrame({'close':[i.close for i in bars], 'date':[i.date for i in bars]})
time_series = np.array([i.close for i in bars])
df
# Out:
#        close                date
# 0    426.295 2021-06-25 04:00:00
# 1    426.885 2021-06-25 12:00:00
# 2    426.535 2021-06-28 04:00:00
# 3    427.205 2021-06-28 12:00:00
# 4    427.995 2021-06-29 04:00:00
# ..       ...                 ...
# 829  406.035 2022-12-02 11:00:00
# 830  405.945 2022-12-02 19:00:00
# 831  403.360 2022-12-05 04:00:00
# 832  400.240 2022-12-05 11:00:00
# 833  400.420 2022-12-05 19:00:00
#
# [834 rows x 2 columns]

# %%
"""get returns"""
df['returns'] = df['close'].pct_change()
returns = np.array(df['returns'].dropna())
returns[0:5]
# Out:
# array([-0.01363374, -0.01218101,  0.04000757,  0.04269911,  0.0109376 ])

# %%
def GetHurst(time_series, max_lag=5):
    lags = range(2, max_lag)
    
    #variances of lagged differences
    tau = [np.std(np.subtract(time_series[lag:], time_series[:-lag])) for lag in lags]
    
    #hurst exponent is the slope of the log plot
    regression = np.polyfit(x=np.log(lags), y=np.log(tau), deg=1)
    
    return regression[0]

# %%
max_lags = [5, 10, 30, 100, 300]
for i in max_lags:
    print(GetHurst(time_series=time_series, max_lag=i))
# Out:
# 0.5010967434731647
# 0.4991682130560413
# 0.48189360065690673
# 0.432548549816401
# 0.32952678096131766

# %%
df['close'].plot()
# Out:
# <AxesSubplot:>

# %%
max_lags = [5, 10, 30]
for i in max_lags:
    print(GetHurst(time_series=returns, max_lag=i))
# Out:
# -0.03173854596913254
# -0.012352595490179237
# -0.006478070055894387

# %%
"""testing GBM, trending, and mean reverting"""
sample_size = 1000
scalar = 100

np.random.seed(123)
df_test_data = pd.DataFrame(data={"mean_rev": np.log(np.random.randn(sample_size) + scalar),
                        "gbm": np.log(np.cumsum(np.random.randn(sample_size)) + scalar),
                        "trending": np.log(np.cumsum(np.random.randn(sample_size) + 1) + scalar)})

# %%
"""calculate half life"""
lag = 5
# df = pd.DataFrame({'close': df_test_data['mean_rev']})

# %%
df['lag'] = df['close'].shift(periods=lag)

# %%
df.dropna(inplace = True)
# df.head(10)
# df.tail(20)
X = df['lag']
Y = df['close'] - df['lag']
X = sm.add_constant(X)

# %%
model = sm.OLS(Y,X)
results = model.fit()
results.params
print(results.t_test([1,0]))
# Out:
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            12.6648      3.726      3.399      0.001       5.351      19.979
# ==============================================================================

# %%
results.pvalues
# Out:
# const    0.000709
# lag      0.000596
# dtype: float64

# %%
slope = results.params['lag']

# %%
half_life = -math.log(2)/slope
half_life
# Out:
# 23.115004958980904

# %%
df_ols = pd.DataFrame({'Y': Y, 'X': X['lag']})
df_ols.plot(x='X',y='Y')
plt.scatter(df_ols['X'], df_ols['Y'])

# %%
"""program sequence
1) pick markets - SPY, BTC, commodities, rates, etc
2) determine if trending, mean-reverting, or gbm
 - should focus on longer time intervals to reduce the amount of trades
3) determine indicators for each regime
a) if mean-reverting, calculate half-life for look back window
   - mean-reverting signals?
b) if trending, trending signals ?
 
-

"""

# %%
"""momentum"""

# %%
"""mean reverting"""
def LinearMeanReverting(look_back):
    #lookback can be set to the half-life
    pass

def BuyonGap():
    #buy stocks which gap > 1 std dev below prev day's close
    #only buy those whose opening px is above 20dma of closing prices
    #can do the opposite strategy as well - sellongap
    pass
    
def VIXSandP():
    pass

# %%
array = np.array([10, 11, 11.5, 10.75, 12, 11.75, 12.25, 14, 16, 17, 15.6, 15.75, 16, 14, 16.5, 17, 17.25, 18, 18.75,20])
period = 5
smoothing = 2
k = smoothing / (1 + period)
EMA = np.array([])
EMA = np.append(EMA,array[0:period].sum()/period)

for i in range(period,len(array)):
    new_value = array[i] * k  + EMA[-1] * (1 - k)
    EMA = np.append(EMA, new_value)

# %%
array[0:period]
# Out:
# array([10.  , 11.  , 11.5 , 10.75, 12.  ])

# %%
sum([4,3,5])
# Out:
# 12
