# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from math import sqrt
import pandas_ta as ta
from arch import arch_model
import numpy as np
from ib_insync import *
from collections import deque
from enum import Enum
import datetime
import logging
import math
util.startLoop()

# %%
"""start here
TODO's:
1) get list of simple trending strategies (have MA, finish EMA, maybe couple more) -> Done
2) combine them? or just use one? look at the Carver example on Github -> for now, just use EMA
3) back to actual trading - how to run for >1 contracts? may require multiple threads
4) run live (paper trading) in cloud 
5) Strategies should be objects not just parameters, would make it easier to set multiple strategies at once
including the same strategy (eg EMA) with multiple parameters so could track momentum over various scales simultaneously
6) annotate charts



"""

# %%
"""logging parameters"""
today = datetime.datetime.today().date()
logging.basicConfig(level = logging.INFO,
                   filename = 'algo_log_'+str(today)+'_.log',
                   filemode='w')

# %%
contract_dict = {'Stock':Stock, 'Crypto':Crypto}

class Algo():
    def __init__(self, client, addr, port, client_id):
        self.client = client
        self.addr = addr
        self.port = port
        self.client_id = client_id
        
        self.client.connect(addr, port, client_id)
        
    def SetPaperBalances(self):
        self.USD_balance = 1000
        self.BTC_balance = 0
        
        print('USD balance: {}'.format(self.USD_balance))
        print('BTC balance: {}'.format(self.BTC_balance))
    
    def GetContract(self, contract_type, ticker, exchange, currency):
        return contract_dict[contract_type](ticker, exchange, currency)
    
    def GetHistoricalData(self, contract, duration='1 D', bar_size='1 hour'):
        bars = ib.reqHistoricalData(contract=contract, endDateTime='', durationStr=duration,
                                    barSizeSetting=bar_size, whatToShow='MIDPOINT', useRTH=True)
        return bars
    
    def BuildEMA(self, slow_period, fast_period):
        """using deques instead of dataframes"""
        self.slow_ema = deque(maxlen=slow_period)
        self.fast_ema = deque(maxlen=fast_period)
        
        """need to employ scanner to pull in data"""
        
           
    def GetDMI(self, df):
        df_adx = ta.adx(high=df['high'], low=df['low'], close=df['close'])
        df['ADX'] = df_adx['ADX_14']
        df['DMN'] = df_adx['DMN_14']
        df['DMP'] = df_adx['DMP_14']
        df['DM_diff'] = df['DMP'] > df['DMN']
        return df
        
    
    
    def GetMovingAverages(self, df, low, high, plot=True):
#         print('length:', len(df))
        df_MA = df.copy()
        if len(df) < high:
            return
#         display('in mov avg fn', df_MA)
        
        df_MA[str(low)+'_average'] = df.close.rolling(low).mean()
        df_MA[str(high)+'_average'] = df.close.rolling(high).mean()
#         df_MA.dropna(inplace=True)
        df_MA['MA_diff'] = df_MA[str(high)+'_average'] > df_MA[str(low)+'_average']
        
        if plot:
            df_MA['close'].plot(legend=True)
            df_MA[str(low)+'_average'].plot(legend=True)
            df_MA[str(high)+'_average'].plot(legend=True)
        
#         display('end of mov avg', df_MA)
        return df_MA
    
    
    def PlacePaperOrder(self, order_type, price=None, quantity=None, date=None):
        print('placing order:', order_type)

        if order_type=='sell':
            print(date)
            print('{} @ {}'.format(order_type, price))
            self.BTC_balance -= quantity
            self.USD_balance += quantity * price
            

        elif order_type=='buy':
            print(date)
            print('{} @ {}'.format(order_type, price))
            self.BTC_balance += quantity
            self.USD_balance -= quantity * price

        else:
            return 


        print('USD balance: {}'.format(self.USD_balance))
        print('BTC balance: {}'.format(self.BTC_balance))
        account_balance = self.USD_balance + self.BTC_balance * price
        print('Account balance: {}\n'.format(account_balance))       

    def RunDMI(self, df, ADX_MIN=20):
        for count, row in enumerate(df.iterrows()):
            if count==0:
                sentiment = row[1]['DM_diff']
            else:
                if (row[1]['ADX'] >= ADX_MIN):
                    if row[1]['DM_diff'] == sentiment:
                        self.PlacePaperOrder('no change')
                    else:
                        if row[1]['DM_diff']:
                            self.PlacePaperOrder('buy',row[1]['close'],1, row[1]['date'])
                        else:
                            self.PlacePaperOrder('sell', row[1]['close'],1, row[1]['date'])
                    sentiment = row[1]['DM_diff']
                else: continue                                     
                        
    
    def RunStrategy(self, df):   

        for count, row in enumerate(df.iterrows()):
            if count==0:
                sentiment = row[1]['MA_diff']
            else:
                if row[1]['MA_diff'] == sentiment:
                    self.PlacePaperOrder('no change')
                else:
                    if row[1]['MA_diff']:
                        self.PlacePaperOrder('sell',row[1]['close'],1)
                    else:
                        self.PlacePaperOrder('buy', row[1]['close'],1)
                    sentiment = row[1]['MA_diff']


def Main(client_id):
    
    ib = IB()
    algo = Algo(ib, '127.0.0.1', 7497, client_id=client_id)
    
    contract = algo.GetContract('Crypto','BTC', 'PAXOS', 'USD')
    
    bars = algo.GetHistoricalData(contract, '180 D', '1 day')
    
    df = util.df(bars)
    
    algo.SetPaperBalances()
    
#     df_MA =  algo.GetMovingAverages(df, 10, 30, True)
    df_DMI = algo.GetDMI(df)
    
#     algo.RunStrategy(df_MA)
    algo.RunDMI(df_DMI)
    
    print('USD balance: {}'.format(algo.USD_balance))
    print('BTC balance: {}'.format(algo.BTC_balance))

    account_value = algo.USD_balance + algo.BTC_balance * bars[-1].close
    print('Account value: {}'.format(account_value))

# %%
class Account():
    def __init__(self, USD_balance: int, BTC_balance: int, BTC_price: float = None):
        self.USD_balance = USD_balance
        self.BTC_balance = BTC_balance
        self.BTC_price = BTC_price                 
        self.df_account = pd.DataFrame(columns=['Date', 'USD', 'BTC', 'Account Value', 'BTC Px'])
        self.log = dict()
        
    def __call__(self):
        return self.returnBalance()
        
    def __repr__(self):
        return 'USD balance: '+ str(self.USD_balance) + '\nBTC balance: ' + str(self.BTC_balance) + '\nAccount Value: '+str(self.USD_balance + self.BTC_balance * self.BTC_price) + '\nBTC Price:' + str(self.BTC_price)
        
        
    def updateBTCPrice(self, BTC_price: float):
        self.BTC_price = BTC_price
        
    def closePosition(self):
        self.BTC_balance = 0
        self.USD_balance -= self.BTC_balance * self.BTC_price
    
    def tradeBTC(self, signal: Signal, quantity: int, date: datetime): #-> order:
#         print(signal)
#         print(str(signal), str(quantity)+' @ ', str(self.BTC_price))
#         logging.info(str(signal), str(quantity)+' @ ', str(self.BTC_price))
        
        self.log[str(date)] = str(signal) + str(quantity)
        logging.info("%s, %s @, %s" %(signal, quantity, self.BTC_price))
        
        #first exit current position if there is one 
        if self.BTC_balance != 0:
            self.USD_balance += self.BTC_balance * self.BTC_price
            self.BTC_balance = 0
        
        direction = 1 if signal==Signal.BUY else -1
        
        self.BTC_balance += direction * quantity
        self.USD_balance -= direction * quantity * self.BTC_price
        
        order_type = 'BUY' if signal==Signal.BUY else 'SELL'
        
        order = LimitOrder(order_type, quantity, round(self.BTC_price, 0),
                           tif='GTC')
        return order 
        
#         self.updateBalance([date, self.USD_balance, self.BTC_balance, self.total])
                
    def updateBalance(self, date):
        total = self.USD_balance + self.BTC_balance * self.BTC_price
        self.df_account.loc[len(self.df_account.index)] = [date, self.USD_balance,
                                                          self.BTC_balance, total, self.BTC_price]       
        
    def returnBalance(self):
        return self.df_account
    
    def plotBalance(self):
        self.df_account.plot(x='Date', y=['Account Value'])

# %%
"""real time updates"""

from collections import deque
import pandas as pd


Sentiment = Enum('Sentiment','BEAR NEUTRAL BULL')
Signal = Enum('Signal','BUY SELL')

strategy_dict = dict()

def AddStrategy(strategy_fn):
    strategy_dict[strategy_fn.__name__] = strategy_fn
    return strategy_fn
  
def LogFunctionCall(fn):
    logging.info(fn.__name__+' called')
    return fn

def PrintFunction(fn):
    print(fn)
#     print(fn.__code__.co_varnames)
    return fn
    


class Strategy():
    def __init__(self, account: Account, ib, client_id: int, paper_trading: bool = True):
        self.client_id = client_id
        self.ib = ib     
        self.algo = Algo(ib, '127.0.0.1', 7497, client_id=self.client_id)
        self.algo.SetPaperBalances()
        self.contract = Crypto('BTC', exchange='PAXOS', currency='USD')
        self.account = account
        self.paper_trading=paper_trading
        self.sentiment = dict()
        self.signal = dict()
        self.trades = list()


    
    def onBarUpdate(self, bars, newBar):
        if newBar:
            print('on bar update', bars[-1])
            self.strategy_params['close'] = bars[-1].close 
            self.strategy(**self.strategy_params)
    #         self.low_deque.append(bars[-1].close)
    #         self.high_deque.append(bars[-1].close)
    #         self.account.updateBTCPrice(BTC_price=bars[-1].close)
    #         self.MovingAverage(self.low_deque, self.high_deque, bars[-1].close)
            self.SignalProcess(self.strategy.__name__, date=bars[-1].time)
    
#     def MovingAverage(self, low_deque, high_deque, closing_value):
  
    
    def SetSentiment(self, current_sentiment):                 
        if self.sentiment.get(self.strategy.__name__) is None:
            self.sentiment[self.strategy.__name__] = current_sentiment
            return

        if self.sentiment[self.strategy.__name__] != current_sentiment:
            print('change in sentiment')
            
            if current_sentiment == Sentiment.BEAR:
                self.signal[self.strategy.__name__] = Signal.SELL               

            elif current_sentiment == Sentiment.BULL:
                self.signal[self.strategy.__name__] = Signal.BUY                        
#         else:
#             print('no change in sentiment')

                              
        self.sentiment[self.strategy.__name__] = current_sentiment
#         print('ending sentiment:', self.sentiment['EMAverage'])
        
    
    @AddStrategy
    @LogFunctionCall
    def EMAverage(self, smoothing, period, close):
        if not hasattr(self, "SMA_lst"):
            self.SMA_lst = []
        
        self.SMA_lst.append(close)        
        self.account.updateBTCPrice(BTC_price=close)        
        
        if len(self.SMA_lst) < period:            
            return            
        
        k = smoothing / (1 + period)
        
        if len(self.SMA_lst) == period:            
            self.EMA = np.array([])
            self.EMA = np.append(self.EMA,sum(self.SMA_lst[0:period])/period)
            return
        
        new_value = close * k  + self.EMA[-1] * (1 - k)
        self.EMA = np.append(self.EMA, new_value)
        print(self.EMA)
        
        """below code should be made abstract as is repeated for every strategy"""
        
        print('last value:', self.EMA[-1])
        print('close', close)
        if close < self.EMA[-1]:            
            current_sentiment_EMA = Sentiment.BEAR
            print('bearish')
        elif close > self.EMA[-1]:
            current_sentiment_EMA = Sentiment.BULL
            print('bullish')
        else:
            current_sentiment_EMA = Sentiment.NEUTRAL   
            
        
        self.SetSentiment(current_sentiment_EMA)            
            
        
#         if self.sentiment.get('EMAverage') is None:
#             print('1st setting of EMA sentiment')
#             self.sentiment['EMAverage'] = current_sentiment_EMA
#             return

#         if self.sentiment['EMAverage'] != current_sentiment_EMA:
#             print('change in sentiment')
            
#             if current_sentiment_EMA == Sentiment.BEAR:
#                 self.signal['EMAverage'] = Signal.SELL               

#             elif current_sentiment_EMA == Sentiment.BULL:
#                 self.signal['EMAverage'] = Signal.BUY            
#             print(self.signal['EMAverage'])
            
#         else:
#             print('no change in sentiment')

                              
#         self.sentiment['EMAverage'] = current_sentiment_EMA      
#         print('ending sentiment:', self.sentiment['EMAverage'])
              
    
    
    @AddStrategy
    @LogFunctionCall
    def MovingAverage(self, low, high, close):
        
        if not (hasattr(self, "low_deque") and hasattr(self, "high_deque")):
            low_deque_len, high_deque_len = low, high
            self.low_deque = deque(maxlen=low_deque_len)
            self.high_deque = deque(maxlen=high_deque_len)              

        self.low_deque.append(close)
        self.high_deque.append(close)
        self.account.updateBTCPrice(BTC_price=close)        
        
        if len(self.high_deque) < self.high_deque.maxlen:
            return
        low_avg = sum(self.low_deque)/len(self.low_deque)
        high_avg = sum(self.high_deque)/len(self.high_deque)

        if low_avg < high_avg:
            current_sentiment_MA = Sentiment.BEAR
        elif low_avg > high_avg:
            current_sentiment_MA = Sentiment.BULL
        else:
            current_sentiment_MA = Sentiment.NEUTRAL     
            
        self.SetSentiment(current_sentiment_MA) 
        
#         if self.sentiment.get('MovingAverage') is None:
#             print('1st setting of MA sentiment')
#             self.sentiment['MovingAverage'] = current_sentiment_MA
#             return

#         if self.sentiment['MovingAverage'] != current_sentiment_MA:
#             print('change in sentiment')
            
#             if current_sentiment_MA == Sentiment.BEAR:
#                 self.signal['MovingAverage'] = Signal.SELL               

#             elif current_sentiment_MA == Sentiment.BULL:
#                 self.signal['MovingAverage'] = Signal.BUY            
#             print(self.signal['MovingAverage'])
                              
#         self.sentiment['MovingAverage'] = current_sentiment_MA

        
    @LogFunctionCall
    @PrintFunction
    def SignalProcess(self, *signals, date):        
        print('signal dict',self.signal.items())
        signal_list = [values for keys,values in self.signal.items() if keys in signals]
        print('signals', signal_list)
        
        
        if len(set(signal_list))==1 and signal_list[0] is not None: #i.e. all signals are the same
            print(date)
            signal = signal_list[0]
            print(str(signal) + ' @ ' + str(self.account.BTC_price))
            order = self.account.tradeBTC(signal=signal, quantity=1, date=date)
            
            if not self.paper_trading:
                self.trades.append(self.ib.placeOrder(self.contract, order))
            
            self.ClearSignals(*signals)                
        
        self.account.updateBalance(date=date)
        print(self.account)
    
    def ClearSignals(self, *signals):
        for s in signals:
            self.signal[s]=None                  

    def SetStrategy(self, strategy, **kwargs):
        self.strategy = strategy_dict[strategy]
        self.strategy_params = kwargs
        self.strategy_params['self'] = self
        
            
    def RunStrategy(self):             

        bars = ib.reqRealTimeBars(contract=self.contract,
                                  barSize=5,
                                  whatToShow='MIDPOINT',
                                 useRTH=False)
        bars.updateEvent += self.onBarUpdate


        self.ib.sleep(100)
        self.ib.cancelRealTimeBars(bars)        
    
        
    def Backtest(self, duration='360 D', barSize='1 day'):
        self.paper_trading = True
        bars = ib.reqHistoricalData(
            self.contract, endDateTime='', durationStr=duration,
            barSizeSetting=barSize, whatToShow='MIDPOINT', useRTH=True)
        
        df = util.df(bars)
#         print('backtest')
        for row in df.itertuples(name='bar', index=False):    
            self.strategy_params['close'] = row.close 
#             print('calling fn')
            self.strategy(**self.strategy_params)    
#             print('strategy name',self.strategy.__name__)
            self.SignalProcess(self.strategy.__name__, date=row.date)
            
    def PlotEquityCurve(self):
        fig, axs = plt.subplots(2, figsize=(15,15))        
        date = self.account.df_account['Date']
        axs[0].title.set_text('Account Value')
        axs[1].title.set_text('BTC Price')
        axs[0].plot(date, self.account.df_account['Account Value'])
        axs[1].plot(date, self.account.df_account['BTC Px'])
        plt.show()
        
    def PlotSignal(self, signal_values):
        plt.figure(figsize=(15,15)) 
        self.account.df_account['Signal'] = signal_values
        plt.plot(self.account.df_account['Date'], self.account.df_account['Signal'])
        plt.plot(self.account.df_account['Date'], self.account.df_account['BTC Px'])
# Out:
# <function Strategy.SignalProcess at 0x000001CA004609D0>

# %%
ib = IB()
account = Account(USD_balance=1000, BTC_balance=0)
S = Strategy(account, ib, 27, paper_trading=True)

# S.SetStrategy('MovingAverage',low=10,high=30)
S.SetStrategy('EMAverage',smoothing=2, period=20)


# S.RunStrategy()
    
S.Backtest()
# Out:
# USD balance: 1000
# BTC balance: 0
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48667.875
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46951.5
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48335.125
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48647.125
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:47340.625
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48158.625
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:49328.375
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:50556.375
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:51739.375
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46702.25
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46454.625
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46608.875
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:45647.625
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:44766.875
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:46483.0
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:48094.875
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:47456.625
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:47508.375
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:43873.125
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:42009.125
# [47266.51875    46902.51696429]
# last value: 46902.516964285714
# close 43444.5
# bearish
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:43444.5
# [47266.51875    46902.51696429 46701.97963435]
# last value: 46701.97963435374
# close 44796.875
# bearish
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:44796.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251]
# last value: 46293.803002510525
# close 42416.125
# bearish
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:42416.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656]
# last value: 45984.95271655714
# close 43050.875
# bearish
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:43050.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546]
# last value: 45566.671505456456
# close 41593.0
# bearish
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:41593.0
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256]
# last value: 45148.85755255584
# close 41179.625
# bearish
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:41179.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993]
# last value: 45000.07349993148
# close 43586.625
# bearish
# signal dict dict_items([])
# signals []
# USD balance: 1000
# BTC balance: 0
# Account Value: 1000.0
# BTC Price:43586.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428 ]
# last value: 45289.42364279515
# close 48038.25
# bullish
# change in sentiment
# signal dict dict_items([('EMAverage', <Signal.BUY: 1>)])
# signals [<Signal.BUY: 1>]
# 2021-10-01
# Signal.BUY @ 48038.25
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 1000.0
# BTC Price:48038.25
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911 ]
# last value: 45677.37139110037
# close 49362.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 2324.625
# BTC Price:49362.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719]
# last value: 46203.752687186054
# close 51204.375
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 4166.125
# BTC Price:51204.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174]
# last value: 47048.97862173976
# close 55078.625
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 8040.375
# BTC Price:55078.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729]
# last value: 47709.75446728836
# close 53987.125
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 6948.875
# BTC Price:53987.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231]
# last value: 48375.48023230852
# close 54699.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 7661.625
# BTC Price:54699.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495]
# last value: 49245.7321149458
# close 57513.125
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 10474.875
# BTC Price:57513.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971]
# last value: 49824.91238971287
# close 55327.125
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 8288.875
# BTC Price:55327.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117]
# last value: 50533.78978116879
# close 57268.125
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 10229.875
# BTC Price:57268.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782 ]
# last value: 51231.250278200336
# close 57857.125
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 10818.875
# BTC Price:57857.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123]
# last value: 52204.024061228876
# close 61445.375
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 14407.125
# BTC Price:61445.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554 ]
# last value: 53082.48605539755
# close 61427.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 14389.625
# BTC Price:61427.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536]
# last value: 54142.14214535969
# close 64208.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 17170.625
# BTC Price:64208.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866]
# last value: 55309.830988658774
# close 66402.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 19364.625
# BTC Price:66402.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164]
# last value: 56025.51375164365
# close 62824.5
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 15786.25
# BTC Price:62824.5
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149]
# last value: 56499.28625148711
# close 61000.125
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 13961.875
# BTC Price:61000.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373]
# last value: 57086.29470372643
# close 62662.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 15624.625
# BTC Price:62662.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337]
# last value: 57553.68330337154
# close 61993.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 14955.625
# BTC Price:61993.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829]
# last value: 57701.29679828853
# close 59103.625
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 12065.375
# BTC Price:59103.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893]
# last value: 58049.16138892772
# close 61353.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 14315.625
# BTC Price:61353.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046]
# last value: 58476.80078045842
# close 62539.375
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 15501.125
# BTC Price:62539.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851]
# last value: 58760.33165851
# close 61453.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 14415.625
# BTC Price:61453.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008]
# last value: 59224.64531008048
# close 63635.625
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 16597.375
# BTC Price:63635.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769]
# last value: 59573.04813769186
# close 62882.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 15844.625
# BTC Price:62882.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722 ]
# last value: 59734.8411721974
# close 61271.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 14233.625
# BTC Price:61271.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177 ]
# last value: 59870.6539177024
# close 61160.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 14122.625
# BTC Price:61160.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697]
# last value: 60462.48449696884
# close 66084.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 19046.625
# BTC Price:66084.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345]
# last value: 61119.235973448005
# close 67358.375
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 20320.125
# BTC Price:67358.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693]
# last value: 61568.85635692915
# close 65840.25
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 18802.0
# BTC Price:65840.25
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246]
# last value: 61881.10813245971
# close 64847.5
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 17809.25
# BTC Price:64847.5
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842]
# last value: 62096.13354841593
# close 64138.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 17100.625
# BTC Price:64138.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238]
# last value: 62271.22797237632
# close 63934.625
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: -47038.25
# BTC balance: 1
# Account Value: 16896.375
# BTC Price:63934.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644]
# last value: 62031.92054643572
# close 59758.5
# bearish
# change in sentiment
# signal dict dict_items([('EMAverage', <Signal.SELL: 2>)])
# signals [<Signal.SELL: 2>]
# 2021-11-16
# Signal.SELL @ 59758.5
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 12720.25
# BTC Price:59758.5
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678]
# last value: 61880.01144677518
# close 60436.875
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 12041.875
# BTC Price:60436.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708]
# last value: 61511.486547082306
# close 58010.5
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 14468.25
# BTC Price:58010.5
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307]
# last value: 61164.999733074466
# close 57873.375
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 14605.375
# BTC Price:57873.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945]
# last value: 60664.70213944832
# close 55911.875
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 16566.875
# BTC Price:55911.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807]
# last value: 60397.93288807229
# close 57863.625
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 14615.125
# BTC Price:57863.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778]
# last value: 60114.784517779684
# close 57424.875
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 15053.875
# BTC Price:57424.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037]
# last value: 60001.03123037209
# close 58920.375
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 13558.375
# BTC Price:58920.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034]
# last value: 59483.063970336654
# close 54562.375
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 17916.375
# BTC Price:54562.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364]
# last value: 59351.27216363793
# close 58099.25
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 14379.5
# BTC Price:58099.25
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901]
# last value: 59174.960529005744
# close 57500.0
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 14978.75
# BTC Price:57500.0
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767]
# last value: 58949.73809767186
# close 56810.125
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 15668.625
# BTC Price:56810.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075]
# last value: 58769.01304075074
# close 57052.125
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 15426.625
# BTC Price:57052.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592]
# last value: 58266.40465591733
# close 53491.625
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 18987.125
# BTC Price:53491.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678]
# last value: 57373.63992678234
# close 48892.375
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 23586.375
# BTC Price:48892.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423]
# last value: 56714.936124231644
# close 50457.25
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 22021.5
# BTC Price:50457.25
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859]
# last value: 56149.144588590534
# close 50774.125
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 21704.625
# BTC Price:50774.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301]
# last value: 55343.14272301049
# close 47686.125
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 24792.625
# BTC Price:47686.125
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351 ]
# last value: 54687.64103510473
# close 48460.375
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 24018.375
# BTC Price:48460.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605]
# last value: 53920.234746047136
# close 46629.875
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 25848.875
# BTC Price:46629.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605
#  53338.34334166]
# last value: 53338.34334166169
# close 47810.375
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 24668.375
# BTC Price:47810.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605
#  53338.34334166 52947.6082615 ]
# last value: 52947.60826150344
# close 49235.625
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 23243.125
# BTC Price:49235.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605
#  53338.34334166 52947.6082615  52470.34795088]
# last value: 52470.34795088406
# close 47936.375
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 24542.375
# BTC Price:47936.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605
#  53338.34334166 52947.6082615  52470.34795088 51873.51719366]
# last value: 51873.517193657004
# close 46203.625
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 26275.125
# BTC Price:46203.625
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605
#  53338.34334166 52947.6082615  52470.34795088 51873.51719366
#  51411.5036514 ]
# last value: 51411.50365140395
# close 47022.375
# bearish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 72478.75
# BTC balance: -1
# Account Value: 25456.375
# BTC Price:47022.375
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
# ...
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605
#  53338.34334166 52947.6082615  52470.34795088 51873.51719366
#  51411.5036514  51147.32473222 50940.30571011 50946.00278533
#  50964.51442483 50991.4297177  50688.75783982 50373.62614079
#  50071.62603215 49672.72117194 49315.33106033 49026.16857839
#  48543.70014235 48036.28822404 47454.46315508 46909.8476165
#  46518.20736731 46263.62809423 45935.10399002 45669.08218145
#  45330.84816417 44993.32691044 44672.37910944 44485.28347997
#  43903.70886283 43270.37944732 42663.78378567 42128.94723466
#  41503.08321231 41148.87290637 40896.51596291 40671.07396644
#  40379.38835059 39997.50612673 40054.96982894 40447.42508333
#  40814.2298373  41192.79128136 41470.94211171 41554.43572012
#  41615.95374677 41858.5652947  42075.42812378 41963.30401675
#  41779.28696754 41442.48582777 41109.11812989 40783.28545085
#  40557.42493172 40422.27731918 40565.66757449 40903.92542454
#  41182.37300316 41262.75414571 41095.90851279 40761.11960681
#  40547.79869187 40668.61548312 40570.75924664 40360.96074696
#  40213.09543772 40168.78872937 40237.7731361  40298.23521837
#  40466.67710234 40535.83880688 40704.53273003 40851.66056527
#  41146.37146381 41462.82418154 42083.44806902 42621.75063387
#  43045.88152588 43291.45233294 43586.92115838 43812.51200044
#  44023.57038135 43998.28986884 43942.27416704 43827.66472256
#  43462.94665375 43065.91602006 42877.38830386 42582.67275111
#  42367.52534624 42207.74912279 42136.07063491 42045.98057444
#  41969.70861497 41733.53398497 41591.61408164 41277.49607387
#  41048.07978112 40945.06027815 40696.01882309 40490.95750661
#  40225.73536312 40189.41532854 39821.53053534 39455.46810341
#  38645.23304594 37949.65132728 37125.91072468 36310.62160804
#  35713.59812156 35127.62449094 34644.79120609 34131.10871027
#  33731.84835691 33307.18422768 32902.86906314 32564.46486665
#  32277.64678411 31999.33518563 31699.86278699 31597.36395014
#  31599.24595489 31455.82967347 31342.9530379  31172.49322477
#  31198.98196527 31183.9717781  31082.74827542 30978.79605871
#  30786.42262455 30058.38237459 29306.97691035 28573.00291889
#  27837.93121232 27139.16395401 26464.55310125 25932.10756779
#  25377.27589467 24950.38057137 24596.38004076 24239.52241783
#  23859.10361613 23510.22470031 23072.01282409 22718.90445989
#  22441.33022562 22245.00115651 22059.91771303 22036.65174036
#  22013.72062223 21868.69961059 21631.95440958 21441.70875153
#  21360.96267995 21341.43051996 21367.31808949 21561.72827144
#  21761.62319797 21897.90908388 21964.72726636 21957.71752671
#  21858.92300036 21945.15652413 22121.64161707 22291.85432021
#  22356.0467659  22413.74469296 22514.04281744 22508.93159673
#  22550.73573038 22681.96327986 22718.78820559 22804.91551934
#  22939.57832703 23059.39229588 23147.96207723 23223.07283178
#  23228.91113351 23240.90769222 23059.9283882  22868.30425599
#  22739.1919459  22642.20937962 22543.65372442 22364.31765543
#  22148.46597396 21939.67159549 21777.19096734 21596.18468474
#  21436.55995286 21272.30424306 21038.85860087 20845.02682936
#  20703.3933218  20761.27252925 20920.28228837 20860.26730852
#  20774.80137438 20681.47505301 20580.65600034 20479.55780983
#  20338.32611366 20212.97362664 20126.27375744 20001.45006625
#  19924.39529804 19844.03622204 19815.42562946 19776.73033142
#  19749.48220461 19729.21008989 19776.53531942 19809.2105271
#  19828.91666737 19793.98412762 19738.78325833 19670.79199563
#  19620.53799605 19597.28437737 19556.24538905 19553.59106629
#  19521.18953616 19493.58815177 19453.0678516  19428.1685324
#  19420.06914836 19501.24113423 19621.34912145 19716.85158607
#  19802.42524454 19856.44426887 19912.72338612 19945.71401601
#  19975.94363354 20083.81804939 20152.64490183 19963.45253023
#  19605.11181306 19457.29164039 19182.74005559 18903.38385982
#  18705.07349222 18501.32839772 18327.71378841 18164.7291419
#  17936.95731886 17763.63995516 17653.75757848 17548.98304719
#  17450.97275699 17337.08249442 17256.37225685 17241.03918477
#  17209.83307194 17192.86087461 17168.64793417 17151.9790833
#  17121.0644087  17128.7249412  17126.57256585 17126.07755958
#  17185.74874438 17242.2369592  17258.94058213 17223.07719336
#  17163.62936542 17135.03371157 17101.06621523 17070.85752807
#  17045.70443015 17026.14924633 16991.36122287 16953.21967784
#  16919.32970852 16884.66735533 16869.23475006 16848.91477386
#  16844.07765254 16845.03454277 16849.40030061]
# last value: 16849.400300605692
# close 16890.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 12690.5
# BTC balance: 1
# Account Value: 29581.375
# BTC Price:16890.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605
#  53338.34334166 52947.6082615  52470.34795088 51873.51719366
#  51411.5036514  51147.32473222 50940.30571011 50946.00278533
#  50964.51442483 50991.4297177  50688.75783982 50373.62614079
#  50071.62603215 49672.72117194 49315.33106033 49026.16857839
#  48543.70014235 48036.28822404 47454.46315508 46909.8476165
#  46518.20736731 46263.62809423 45935.10399002 45669.08218145
#  45330.84816417 44993.32691044 44672.37910944 44485.28347997
#  43903.70886283 43270.37944732 42663.78378567 42128.94723466
#  41503.08321231 41148.87290637 40896.51596291 40671.07396644
#  40379.38835059 39997.50612673 40054.96982894 40447.42508333
#  40814.2298373  41192.79128136 41470.94211171 41554.43572012
#  41615.95374677 41858.5652947  42075.42812378 41963.30401675
#  41779.28696754 41442.48582777 41109.11812989 40783.28545085
#  40557.42493172 40422.27731918 40565.66757449 40903.92542454
#  41182.37300316 41262.75414571 41095.90851279 40761.11960681
#  40547.79869187 40668.61548312 40570.75924664 40360.96074696
#  40213.09543772 40168.78872937 40237.7731361  40298.23521837
#  40466.67710234 40535.83880688 40704.53273003 40851.66056527
#  41146.37146381 41462.82418154 42083.44806902 42621.75063387
#  43045.88152588 43291.45233294 43586.92115838 43812.51200044
#  44023.57038135 43998.28986884 43942.27416704 43827.66472256
#  43462.94665375 43065.91602006 42877.38830386 42582.67275111
#  42367.52534624 42207.74912279 42136.07063491 42045.98057444
#  41969.70861497 41733.53398497 41591.61408164 41277.49607387
#  41048.07978112 40945.06027815 40696.01882309 40490.95750661
#  40225.73536312 40189.41532854 39821.53053534 39455.46810341
#  38645.23304594 37949.65132728 37125.91072468 36310.62160804
#  35713.59812156 35127.62449094 34644.79120609 34131.10871027
#  33731.84835691 33307.18422768 32902.86906314 32564.46486665
#  32277.64678411 31999.33518563 31699.86278699 31597.36395014
#  31599.24595489 31455.82967347 31342.9530379  31172.49322477
#  31198.98196527 31183.9717781  31082.74827542 30978.79605871
#  30786.42262455 30058.38237459 29306.97691035 28573.00291889
#  27837.93121232 27139.16395401 26464.55310125 25932.10756779
#  25377.27589467 24950.38057137 24596.38004076 24239.52241783
#  23859.10361613 23510.22470031 23072.01282409 22718.90445989
#  22441.33022562 22245.00115651 22059.91771303 22036.65174036
#  22013.72062223 21868.69961059 21631.95440958 21441.70875153
#  21360.96267995 21341.43051996 21367.31808949 21561.72827144
#  21761.62319797 21897.90908388 21964.72726636 21957.71752671
#  21858.92300036 21945.15652413 22121.64161707 22291.85432021
#  22356.0467659  22413.74469296 22514.04281744 22508.93159673
#  22550.73573038 22681.96327986 22718.78820559 22804.91551934
#  22939.57832703 23059.39229588 23147.96207723 23223.07283178
#  23228.91113351 23240.90769222 23059.9283882  22868.30425599
#  22739.1919459  22642.20937962 22543.65372442 22364.31765543
#  22148.46597396 21939.67159549 21777.19096734 21596.18468474
#  21436.55995286 21272.30424306 21038.85860087 20845.02682936
#  20703.3933218  20761.27252925 20920.28228837 20860.26730852
#  20774.80137438 20681.47505301 20580.65600034 20479.55780983
#  20338.32611366 20212.97362664 20126.27375744 20001.45006625
#  19924.39529804 19844.03622204 19815.42562946 19776.73033142
#  19749.48220461 19729.21008989 19776.53531942 19809.2105271
#  19828.91666737 19793.98412762 19738.78325833 19670.79199563
#  19620.53799605 19597.28437737 19556.24538905 19553.59106629
#  19521.18953616 19493.58815177 19453.0678516  19428.1685324
#  19420.06914836 19501.24113423 19621.34912145 19716.85158607
#  19802.42524454 19856.44426887 19912.72338612 19945.71401601
#  19975.94363354 20083.81804939 20152.64490183 19963.45253023
#  19605.11181306 19457.29164039 19182.74005559 18903.38385982
#  18705.07349222 18501.32839772 18327.71378841 18164.7291419
#  17936.95731886 17763.63995516 17653.75757848 17548.98304719
#  17450.97275699 17337.08249442 17256.37225685 17241.03918477
#  17209.83307194 17192.86087461 17168.64793417 17151.9790833
#  17121.0644087  17128.7249412  17126.57256585 17126.07755958
#  17185.74874438 17242.2369592  17258.94058213 17223.07719336
#  17163.62936542 17135.03371157 17101.06621523 17070.85752807
#  17045.70443015 17026.14924633 16991.36122287 16953.21967784
#  16919.32970852 16884.66735533 16869.23475006 16848.91477386
#  16844.07765254 16845.03454277 16849.40030061 16883.73122436]
# last value: 16883.731224357532
# close 17209.875
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 12690.5
# BTC balance: 1
# Account Value: 29900.375
# BTC Price:17209.875
# [47266.51875    46902.51696429 46701.97963435 46293.80300251
#  45984.95271656 45566.67150546 45148.85755256 45000.07349993
#  45289.4236428  45677.3713911  46203.75268719 47048.97862174
#  47709.75446729 48375.48023231 49245.73211495 49824.91238971
#  50533.78978117 51231.2502782  52204.02406123 53082.4860554
#  54142.14214536 55309.83098866 56025.51375164 56499.28625149
#  57086.29470373 57553.68330337 57701.29679829 58049.16138893
#  58476.80078046 58760.33165851 59224.64531008 59573.04813769
#  59734.8411722  59870.6539177  60462.48449697 61119.23597345
#  61568.85635693 61881.10813246 62096.13354842 62271.22797238
#  62031.92054644 61880.01144678 61511.48654708 61164.99973307
#  60664.70213945 60397.93288807 60114.78451778 60001.03123037
#  59483.06397034 59351.27216364 59174.96052901 58949.73809767
#  58769.01304075 58266.40465592 57373.63992678 56714.93612423
#  56149.14458859 55343.14272301 54687.6410351  53920.23474605
#  53338.34334166 52947.6082615  52470.34795088 51873.51719366
#  51411.5036514  51147.32473222 50940.30571011 50946.00278533
#  50964.51442483 50991.4297177  50688.75783982 50373.62614079
#  50071.62603215 49672.72117194 49315.33106033 49026.16857839
#  48543.70014235 48036.28822404 47454.46315508 46909.8476165
#  46518.20736731 46263.62809423 45935.10399002 45669.08218145
#  45330.84816417 44993.32691044 44672.37910944 44485.28347997
#  43903.70886283 43270.37944732 42663.78378567 42128.94723466
#  41503.08321231 41148.87290637 40896.51596291 40671.07396644
#  40379.38835059 39997.50612673 40054.96982894 40447.42508333
#  40814.2298373  41192.79128136 41470.94211171 41554.43572012
#  41615.95374677 41858.5652947  42075.42812378 41963.30401675
#  41779.28696754 41442.48582777 41109.11812989 40783.28545085
#  40557.42493172 40422.27731918 40565.66757449 40903.92542454
#  41182.37300316 41262.75414571 41095.90851279 40761.11960681
#  40547.79869187 40668.61548312 40570.75924664 40360.96074696
#  40213.09543772 40168.78872937 40237.7731361  40298.23521837
#  40466.67710234 40535.83880688 40704.53273003 40851.66056527
#  41146.37146381 41462.82418154 42083.44806902 42621.75063387
#  43045.88152588 43291.45233294 43586.92115838 43812.51200044
#  44023.57038135 43998.28986884 43942.27416704 43827.66472256
#  43462.94665375 43065.91602006 42877.38830386 42582.67275111
#  42367.52534624 42207.74912279 42136.07063491 42045.98057444
#  41969.70861497 41733.53398497 41591.61408164 41277.49607387
#  41048.07978112 40945.06027815 40696.01882309 40490.95750661
#  40225.73536312 40189.41532854 39821.53053534 39455.46810341
#  38645.23304594 37949.65132728 37125.91072468 36310.62160804
#  35713.59812156 35127.62449094 34644.79120609 34131.10871027
#  33731.84835691 33307.18422768 32902.86906314 32564.46486665
#  32277.64678411 31999.33518563 31699.86278699 31597.36395014
#  31599.24595489 31455.82967347 31342.9530379  31172.49322477
#  31198.98196527 31183.9717781  31082.74827542 30978.79605871
#  30786.42262455 30058.38237459 29306.97691035 28573.00291889
#  27837.93121232 27139.16395401 26464.55310125 25932.10756779
#  25377.27589467 24950.38057137 24596.38004076 24239.52241783
#  23859.10361613 23510.22470031 23072.01282409 22718.90445989
#  22441.33022562 22245.00115651 22059.91771303 22036.65174036
#  22013.72062223 21868.69961059 21631.95440958 21441.70875153
#  21360.96267995 21341.43051996 21367.31808949 21561.72827144
#  21761.62319797 21897.90908388 21964.72726636 21957.71752671
#  21858.92300036 21945.15652413 22121.64161707 22291.85432021
#  22356.0467659  22413.74469296 22514.04281744 22508.93159673
#  22550.73573038 22681.96327986 22718.78820559 22804.91551934
#  22939.57832703 23059.39229588 23147.96207723 23223.07283178
#  23228.91113351 23240.90769222 23059.9283882  22868.30425599
#  22739.1919459  22642.20937962 22543.65372442 22364.31765543
#  22148.46597396 21939.67159549 21777.19096734 21596.18468474
#  21436.55995286 21272.30424306 21038.85860087 20845.02682936
#  20703.3933218  20761.27252925 20920.28228837 20860.26730852
#  20774.80137438 20681.47505301 20580.65600034 20479.55780983
#  20338.32611366 20212.97362664 20126.27375744 20001.45006625
#  19924.39529804 19844.03622204 19815.42562946 19776.73033142
#  19749.48220461 19729.21008989 19776.53531942 19809.2105271
#  19828.91666737 19793.98412762 19738.78325833 19670.79199563
#  19620.53799605 19597.28437737 19556.24538905 19553.59106629
#  19521.18953616 19493.58815177 19453.0678516  19428.1685324
#  19420.06914836 19501.24113423 19621.34912145 19716.85158607
#  19802.42524454 19856.44426887 19912.72338612 19945.71401601
#  19975.94363354 20083.81804939 20152.64490183 19963.45253023
#  19605.11181306 19457.29164039 19182.74005559 18903.38385982
#  18705.07349222 18501.32839772 18327.71378841 18164.7291419
#  17936.95731886 17763.63995516 17653.75757848 17548.98304719
#  17450.97275699 17337.08249442 17256.37225685 17241.03918477
#  17209.83307194 17192.86087461 17168.64793417 17151.9790833
#  17121.0644087  17128.7249412  17126.57256585 17126.07755958
#  17185.74874438 17242.2369592  17258.94058213 17223.07719336
#  17163.62936542 17135.03371157 17101.06621523 17070.85752807
#  17045.70443015 17026.14924633 16991.36122287 16953.21967784
#  16919.32970852 16884.66735533 16869.23475006 16848.91477386
#  16844.07765254 16845.03454277 16849.40030061 16883.73122436
#  16913.10206013]
# last value: 16913.102060133006
# close 17192.125
# bullish
# signal dict dict_items([('EMAverage', None)])
# signals [None]
# USD balance: 12690.5
# BTC balance: 1
# Account Value: 29882.625
# BTC Price:17192.125

# %%
# S.account.log
missing = len(S.account.df_account) - len(S.EMA)
S.EMA = np.insert(S.EMA, 0, [0]*missing)

# %%
# account.plotBalance()
S.PlotEquityCurve()
S.PlotSignal(S.EMA)

# %%
S.account.log
# Out:
# {'2021-10-01': 'Signal.BUY1',
#  '2021-11-16': 'Signal.SELL1',
#  '2021-12-23': 'Signal.BUY1',
#  '2021-12-28': 'Signal.SELL1',
#  '2022-02-04': 'Signal.BUY1',
#  '2022-02-17': 'Signal.SELL1',
#  '2022-02-28': 'Signal.BUY1',
#  '2022-03-04': 'Signal.SELL1',
#  '2022-03-09': 'Signal.BUY1',
#  '2022-03-10': 'Signal.SELL1',
#  '2022-03-16': 'Signal.BUY1',
#  '2022-04-06': 'Signal.SELL1',
#  '2022-05-31': 'Signal.BUY1',
#  '2022-06-01': 'Signal.SELL1',
#  '2022-06-06': 'Signal.BUY1',
#  '2022-06-07': 'Signal.SELL1',
#  '2022-07-18': 'Signal.BUY1',
#  '2022-07-25': 'Signal.SELL1',
#  '2022-07-27': 'Signal.BUY1',
#  '2022-08-04': 'Signal.SELL1',
#  '2022-08-05': 'Signal.BUY1',
#  '2022-08-19': 'Signal.SELL1',
#  '2022-09-09': 'Signal.BUY1',
#  '2022-09-13': 'Signal.SELL1',
#  '2022-10-04': 'Signal.BUY1',
#  '2022-10-07': 'Signal.SELL1',
#  '2022-10-25': 'Signal.BUY1',
#  '2022-11-08': 'Signal.SELL1',
#  '2022-12-08': 'Signal.BUY1',
#  '2022-12-09': 'Signal.SELL1',
#  '2022-12-13': 'Signal.BUY1',
#  '2022-12-16': 'Signal.SELL1',
#  '2023-01-05': 'Signal.BUY1'}

# %%
datetime.datetime.strptime((list(S.account.log.keys())[0]), '%Y-%m-%d').date()
# Out:
# datetime.date(2021, 10, 1)

# %%
# def PlotEquity(df):
fig, axs = plt.subplots(2, figsize=(15,15))


date = account.df_account['Date']
axs[0].title.set_text('Account Value')
axs[1].title.set_text('BTC Price')
axs[0].plot(date, account.df_account['Account Value'])



# axs[1].annotate('test',xy=(10, 20000))
axs[1].plot(date, account.df_account['BTC Px'])

for d, trade in S.account.log.items():
    axs[1].annotate(trade,(mdates.date2num(datetime.datetime(d),20000)))
    
    
# axs[1].annotate('test',(mdates.date2num(datetime.datetime(2022,1,1)), 20000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-30d038e0d551> in <module>
#      14
#      15 for d, trade in S.account.log.items():
# ---> 16     axs[1].annotate(trade,(mdates.date2num(datetime.datetime(d),20000)))
#      17
#      18
#
# TypeError: an integer is required (got type str)

# %%
from matplotlib import pyplot as plt, dates as mdates
plt.plot(S.account.df_account['Date'], S.account.df_account['BTC Px'])
plt.annotate('test',(mdates.date2num(datetime.datetime(2022,1,1)), 20000))
# plt.show()


# from matplotlib import pyplot as plt, dates as mdates
# plt.rcParams["figure.figsize"] = [7.00, 3.50]
# plt.rcParams["figure.autolayout"] = True
# x = [dt.datetime(2021, 1, 1), dt.datetime(2021, 1, 2),
#    dt.datetime(2021, 1, 3), dt.datetime(2021, 1, 4)]
# y = [1, 3, 2, 5]
# fig, ax = plt.subplots()
# ax.plot_date(x, y, linestyle='-.')
# ax.annotate('Point', (mdates.date2num(x[1]), y[1]), xytext=(15, 15),
#    textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))
# fig.autofmt_xdate()
# plt.show()
# Out:
# Text(18993.0, 20000, 'test')

# %%
ib.disconnect()

# %%
"""calculate hurst exponent
H < 0.5: mean-reverting
H = 0.5: GBM
H > 0.5: trending
"""
"""https://towardsdatascience.com/introduction-to-the-hurst-exponent-with-code-in-python-4da0414ca52e#:~:text=To%20calculate%20the%20Hurst%20exponent,versus%20the%20mentioned%20standard%20deviations.
"""

# BTC - short duration - 5 min barsize setting over 7D  - appears mean reverting; half-life was 100 bars
# SPY - short duration - 5 mins over 7d - appears trending 

ib = IB()
ib.connect('127.0.0.1', 7497, 7)
# contract = Crypto('BTC', exchange='PAXOS', currency='USD')
contract = Stock('SPY', 'SMART', currency='USD')
bars = ib.reqHistoricalData(contract=contract, endDateTime='', durationStr='365 D',
                                    barSizeSetting='8 hours', whatToShow='MIDPOINT', useRTH=False)

# %%
df = pd.DataFrame({'close':[i.close for i in bars], 'date':[i.date for i in bars]})
time_series = np.array([i.close for i in bars])
df
# Out:
#        close                date
# 0    426.295 2021-06-25 04:00:00
# 1    426.885 2021-06-25 12:00:00
# 2    426.535 2021-06-28 04:00:00
# 3    427.205 2021-06-28 12:00:00
# 4    427.995 2021-06-29 04:00:00
# ..       ...                 ...
# 829  406.035 2022-12-02 11:00:00
# 830  405.945 2022-12-02 19:00:00
# 831  403.360 2022-12-05 04:00:00
# 832  400.240 2022-12-05 11:00:00
# 833  400.420 2022-12-05 19:00:00
#
# [834 rows x 2 columns]

# %%
"""get returns"""
df['returns'] = df['close'].pct_change()
returns = np.array(df['returns'].dropna())
returns[0:5]
# Out:
# array([-0.01363374, -0.01218101,  0.04000757,  0.04269911,  0.0109376 ])

# %%
def GetHurst(time_series, max_lag=5):
    lags = range(2, max_lag)
    
    #variances of lagged differences
    tau = [np.std(np.subtract(time_series[lag:], time_series[:-lag])) for lag in lags]
    
    #hurst exponent is the slope of the log plot
    regression = np.polyfit(x=np.log(lags), y=np.log(tau), deg=1)
    
    return regression[0]

# %%
max_lags = [5, 10, 30, 100, 300]
for i in max_lags:
    print(GetHurst(time_series=time_series, max_lag=i))
# Out:
# 0.5010967434731647
# 0.4991682130560413
# 0.48189360065690673
# 0.432548549816401
# 0.32952678096131766

# %%
df['close'].plot()
# Out:
# <AxesSubplot:>

# %%
max_lags = [5, 10, 30]
for i in max_lags:
    print(GetHurst(time_series=returns, max_lag=i))
# Out:
# -0.03173854596913254
# -0.012352595490179237
# -0.006478070055894387

# %%
"""testing GBM, trending, and mean reverting"""
sample_size = 1000
scalar = 100

np.random.seed(123)
df_test_data = pd.DataFrame(data={"mean_rev": np.log(np.random.randn(sample_size) + scalar),
                        "gbm": np.log(np.cumsum(np.random.randn(sample_size)) + scalar),
                        "trending": np.log(np.cumsum(np.random.randn(sample_size) + 1) + scalar)})

# %%
"""calculate half life"""
lag = 5
# df = pd.DataFrame({'close': df_test_data['mean_rev']})

# %%
df['lag'] = df['close'].shift(periods=lag)

# %%
df.dropna(inplace = True)
# df.head(10)
# df.tail(20)
X = df['lag']
Y = df['close'] - df['lag']
X = sm.add_constant(X)

# %%
model = sm.OLS(Y,X)
results = model.fit()
results.params
print(results.t_test([1,0]))
# Out:
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            12.6648      3.726      3.399      0.001       5.351      19.979
# ==============================================================================

# %%
results.pvalues
# Out:
# const    0.000709
# lag      0.000596
# dtype: float64

# %%
slope = results.params['lag']

# %%
half_life = -math.log(2)/slope
half_life
# Out:
# 23.115004958980904

# %%
df_ols = pd.DataFrame({'Y': Y, 'X': X['lag']})
df_ols.plot(x='X',y='Y')
plt.scatter(df_ols['X'], df_ols['Y'])

# %%
"""program sequence
1) pick markets - SPY, BTC, commodities, rates, etc
2) determine if trending, mean-reverting, or gbm
 - should focus on longer time intervals to reduce the amount of trades
3) determine indicators for each regime
a) if mean-reverting, calculate half-life for look back window
   - mean-reverting signals?
b) if trending, trending signals ?
 
-

"""

# %%
"""momentum"""

# %%
"""mean reverting"""
def LinearMeanReverting(look_back):
    #lookback can be set to the half-life
    pass

def BuyonGap():
    #buy stocks which gap > 1 std dev below prev day's close
    #only buy those whose opening px is above 20dma of closing prices
    #can do the opposite strategy as well - sellongap
    pass
    
def VIXSandP():
    pass

# %%
array = np.array([10, 11, 11.5, 10.75, 12, 11.75, 12.25, 14, 16, 17, 15.6, 15.75, 16, 14, 16.5, 17, 17.25, 18, 18.75,20])
period = 5
smoothing = 2
k = smoothing / (1 + period)
EMA = np.array([])
EMA = np.append(EMA,array[0:period].sum()/period)

for i in range(period,len(array)):
    new_value = array[i] * k  + EMA[-1] * (1 - k)
    EMA = np.append(EMA, new_value)

# %%
array[0:period]
# Out:
# array([10.  , 11.  , 11.5 , 10.75, 12.  ])

# %%
sum([4,3,5])
# Out:
# 12
