# %%
# %pip install ib_insync
# Out:
# Collecting ib_insync
#   Using cached ib_insync-0.9.70-py3-none-any.whl (70 kB)
# Collecting eventkit
#   Using cached eventkit-0.8.9-py3-none-any.whl (31 kB)
# Requirement already satisfied: nest-asyncio in c:\users\kushwaha\anaconda3\lib\site-packages (from ib_insync) (1.4.2)
# Requirement already satisfied: numpy in c:\users\kushwaha\anaconda3\lib\site-packages (from eventkit->ib_insync) (1.19.2)
# Installing collected packages: eventkit, ib-insync
# Successfully installed eventkit-0.8.9 ib-insync-0.9.70
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in c:\users\kushwaha\anaconda3\lib\site-packages (1.4.2)Note: you may need to restart the kernel to use updated packages.

# %%
from ib_insync import *
util.startLoop()

# import nest_asyncio
# nest_asyncio.apply()


ib = IB()
# ib.disconnect()
ib.connect('127.0.0.1', 7497, clientId=4)


contract = Crypto('BTC', exchange='PAXOS', currency='USD')
bars = ib.reqHistoricalData(
    contract, endDateTime='', durationStr='3 D',
    barSizeSetting='1 hour', whatToShow='MIDPOINT', useRTH=True)

# convert to pandas dataframe:
df = util.df(bars)
print(df)
# Out:
#                   date       open       high        low      close  volume  \
# 0  2022-07-31 03:00:00  23787.125  23824.125  23683.625  23723.125    -1.0
# 1  2022-07-31 04:00:00  23723.125  23752.125  23602.625  23607.375    -1.0
# 2  2022-07-31 05:00:00  23607.375  23758.375  23586.625  23758.375    -1.0
# 3  2022-07-31 06:00:00  23758.375  23858.375  23731.625  23841.125    -1.0
# 4  2022-07-31 07:00:00  23841.125  23852.875  23767.125  23822.125    -1.0
# ..                 ...        ...        ...        ...        ...     ...
# 63 2022-08-02 18:00:00  23093.625  23149.875  23037.125  23106.375    -1.0
# 64 2022-08-02 19:00:00  23106.375  23125.875  22944.125  22991.625    -1.0
# 65 2022-08-02 20:00:00  22991.625  23068.875  22757.375  22797.625    -1.0
# 66 2022-08-02 21:00:00  22797.625  22833.125  22701.375  22810.125    -1.0
# 67 2022-08-02 22:00:00  22810.125  22836.625  22778.375  22828.375    -1.0
#
#     average  barCount
# 0      -1.0        -1
# 1      -1.0        -1
# 2      -1.0        -1
# 3      -1.0        -1
# 4      -1.0        -1
# ..      ...       ...
# 63     -1.0        -1
# 64     -1.0        -1
# 65     -1.0        -1
# 66     -1.0        -1
# 67     -1.0        -1
#
# [68 rows x 8 columns]

# %%
# Out:
# BarData(date=datetime.datetime(2022, 8, 2, 22, 0), open=22810.125, high=22836.625, low=22778.375, close=22828.375, volume=-1.0, average=-1.0, barCount=-1)

# %%
def GetMovingAverages(df, low, high):
    df[str(low)+'_average'] = df.close.rolling(low).mean()
    df[str(high)+'_average'] = df.close.rolling(high).mean()
    df2 = df.dropna()
    df2['MA_diff'] = df[str(high)+'_average'] > df[str(low)+'_average']
    return df2

# %%
df_MA =  GetMovingAverages(df, 5, 10)
# Out:
# <ipython-input-52-7184740e6041>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['MA_diff'] = df[str(high)+'_average'] > df[str(low)+'_average']

# %%
df_MA['close'].plot(legend=True)
df_MA['5_average'].plot(legend=True)
df_MA['10_average'].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
def PlaceOrder(order_type, USD_balance, BTC_balance, price=None, quantity=None):
        
    if order_type=='sell':
        print('{} @ {}'.format(order_type, price))
        BTC_balance -= quantity
        USD_balance += quantity * price
    
    elif order_type=='buy':
        print('{} @ {}'.format(order_type, price))
        BTC_balance += quantity
        USD_balance -= quantity * price
    
    else:
        return USD_balance, BTC_balance   
 
        
    print('USD balance: {}'.format(USD_balance))
    print('BTC balance: {}'.format(BTC_balance))
    account_balance = USD_balance + BTC_balance * price
    print('Account balance: {}\n'.format(account_balance))
    
    
    return USD_balance, BTC_balance   
    
    
    
def GetSignals(df):
    USD_balance = 1000
    BTC_balance = 0
    
    for count, row in enumerate(df.iterrows()):
        if count==0:
            sentiment = row[1]['MA_diff']
        else:
            if row[1]['MA_diff'] == sentiment:
                USD_balance, BTC_balance = PlaceOrder('no change', USD_balance, BTC_balance)
            else:
                if row[1]['MA_diff']:
                    USD_balance, BTC_balance = PlaceOrder('sell', USD_balance, BTC_balance, row[1]['close'],1)
                else:
                    USD_balance, BTC_balance = PlaceOrder('buy', USD_balance, BTC_balance, row[1]['close'],1)
                sentiment = row[1]['MA_diff']
    print('USD balance: {}'.format(USD_balance))
    print('BTC balance: {}'.format(BTC_balance))
  
    account_value = USD_balance + BTC_balance * row[1]['close']
    print('Account value: {}'.format(account_value))

# %%
GetSignals(df_MA)
# df_MA
# Out:
# buy @ 23338.875
# USD balance: -22338.875
# BTC balance: 1
# Account balance: 1000.0
#
# sell @ 22966.625
# USD balance: 627.75
# BTC balance: 0
# Account balance: 627.75
#
# buy @ 23194.375
# USD balance: -22566.625
# BTC balance: 1
# Account balance: 627.75
#
# sell @ 22855.125
# USD balance: 288.5
# BTC balance: 0
# Account balance: 288.5
#
# buy @ 23026.625
# USD balance: -22738.125
# BTC balance: 1
# Account balance: 288.5
#
# sell @ 23106.375
# USD balance: 368.25
# BTC balance: 0
# Account balance: 368.25
#
# USD balance: 368.25
# BTC balance: 0
# Account value: 368.25

# %%
def Backtest():
    USD_balance = 1000
    BTC_balance = 0

# %%
from ib_insync import *
util.startLoop()

class Algo():
    def __init__(self, client, addr, port, client_id):
        self.client = client
        self.addr = addr
        self.port = port
        self.client_id = client_id
        
        self.client.connect(addr, port, client_id)
        
    def SetPaperBalances(self):
        self.USD_balance = 1000
        self.BTC_balance = 0
        
        print('USD balance: {}'.format(self.USD_balance))
        print('BTC balance: {}'.format(self.BTC_balance))
    
    def GetContract(self, ticker, exchange, currency):
        return Crypto(ticker, exchange, currency)
    
    def GetHistoricalData(self, duration='1 D', bar_size='1 hour'):
        bars = ib.reqHistoricalData(contract, endDateTime='', durationStr=duration,
                                    barSizeSetting=bar_size, whatToShow='MIDPOINT', useRTH=True)
        return bars
    
    def GetMovingAverages(self, df, low, high, plot=True):
        df[str(low)+'_average'] = df.close.rolling(low).mean()
        df[str(high)+'_average'] = df.close.rolling(high).mean()
        df.dropna(inplace=True)
        df['MA_diff'] = df[str(high)+'_average'] > df[str(low)+'_average']
        
        if plot:
            df['close'].plot(legend=True)
            df[str(low)+'_average'].plot(legend=True)
            df[str(high)+'_average'].plot(legend=True)
        
        return df
    
    
    def PlacePaperOrder(self, order_type, price=None, quantity=None):

        if order_type=='sell':
            print('{} @ {}'.format(order_type, price))
            self.BTC_balance -= quantity
            self.USD_balance += quantity * price
            

        elif order_type=='buy':
            print('{} @ {}'.format(order_type, price))
            self.BTC_balance += quantity
            self.USD_balance -= quantity * price

        else:
            return 


        print('USD balance: {}'.format(self.USD_balance))
        print('BTC balance: {}'.format(self.BTC_balance))
        account_balance = self.USD_balance + self.BTC_balance * price
        print('Account balance: {}\n'.format(account_balance))       

    
    
    def RunStrategy(self, df):   

        for count, row in enumerate(df.iterrows()):
            if count==0:
                sentiment = row[1]['MA_diff']
            else:
                if row[1]['MA_diff'] == sentiment:
                    self.PlacePaperOrder('no change')
                else:
                    if row[1]['MA_diff']:
                        self.PlacePaperOrder('sell',row[1]['close'],1)
                    else:
                        self.PlacePaperOrder('buy', row[1]['close'],1)
                    sentiment = row[1]['MA_diff']


def Main(client_id):
    ib = IB()
    algo = Algo(ib, '127.0.0.1', 7497, client_id=client_id)
    
    contract = algo.GetContract('BTC', 'PAXOS', 'USD')
    bars = algo.GetHistoricalData('7 D', '1 hour')
    
    df = util.df(bars)
    
    algo.SetPaperBalances()
    
    df_MA =  algo.GetMovingAverages(df, 5, 10, True)
    
    algo.RunStrategy(df_MA)
    
    print('USD balance: {}'.format(algo.USD_balance))
    print('BTC balance: {}'.format(algo.BTC_balance))

    account_value = algo.USD_balance + algo.BTC_balance * bars[-1].close
    print('Account value: {}'.format(account_value))

# %%
Main(7)
# Out:
# USD balance: 1000
# BTC balance: 0
# buy @ 21127.875
# USD balance: -20127.875
# BTC balance: 1
# Account balance: 1000.0
#
# sell @ 21081.125
# USD balance: 953.25
# BTC balance: 0
# Account balance: 953.25
#
# buy @ 20942.875
# USD balance: -19989.625
# BTC balance: 1
# Account balance: 953.25
#
# sell @ 22980.875
# USD balance: 2991.25
# BTC balance: 0
# Account balance: 2991.25
#
# buy @ 23750.125
# USD balance: -20758.875
# BTC balance: 1
# Account balance: 2991.25
#
# sell @ 23789.375
# USD balance: 3030.5
# BTC balance: 0
# Account balance: 3030.5
#
# buy @ 23955.625
# USD balance: -20925.125
# BTC balance: 1
# Account balance: 3030.5
#
# sell @ 23522.875
# USD balance: 2597.75
# BTC balance: 0
# Account balance: 2597.75
#
# buy @ 23798.375
# USD balance: -21200.625
# BTC balance: 1
# Account balance: 2597.75
#
# sell @ 23607.375
# USD balance: 2406.75
# BTC balance: 0
# Account balance: 2406.75
#
# buy @ 23734.875
# USD balance: -21328.125
# BTC balance: 1
# Account balance: 2406.75
#
# sell @ 23752.125
# USD balance: 2424.0
# BTC balance: 0
# Account balance: 2424.0
#
# buy @ 23812.125
# USD balance: -21388.125
# BTC balance: 1
# Account balance: 2424.0
#
# sell @ 23596.25
# USD balance: 2208.125
# BTC balance: 0
# Account balance: 2208.125
#
# buy @ 23338.875
# USD balance: -21130.75
# BTC balance: 1
# Account balance: 2208.125
#
# sell @ 22966.625
# USD balance: 1835.875
# BTC balance: 0
# Account balance: 1835.875
#
# buy @ 23194.375
# USD balance: -21358.5
# BTC balance: 1
# Account balance: 1835.875
#
# sell @ 22855.125
# USD balance: 1496.625
# BTC balance: 0
# Account balance: 1496.625
#
# buy @ 23026.625
# USD balance: -21530.0
# BTC balance: 1
# Account balance: 1496.625
#
# sell @ 23106.375
# USD balance: 1576.375
# BTC balance: 0
# Account balance: 1576.375
#
# USD balance: 1576.375
# BTC balance: 0
# Account value: 1576.375
# Peer closed connection.
# Peer closed connection.
